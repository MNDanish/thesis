# %%
import yfinance as yf
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from datetime import datetime
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras import callbacks
from scipy.stats import wilcoxon, mannwhitneyu
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_tweets = pd.read_csv('/content/drive/My Drive/thesis/datasets/twitter comments/tweets_sentiment.csv')
df_news = pd.read_csv('/content/drive/My Drive/thesis/datasets/news articles/news_sentiment_updated2.csv')
df_political_news = pd.read_csv('/content/drive/My Drive/thesis/datasets/news articles/political_news_sentiment.csv')

# %%
company_ticker = 'AAPL'
df_tweets.drop(columns='body', inplace=True)
df_tweets = df_tweets[df_tweets['ticker_symbol'] == company_ticker].reset_index(drop=True)
df_news = df_news[df_news['Company'] == 'Apple'].reset_index(drop=True)

# %%
dates = df_tweets['date'].unique()
avg_sentiment = []
tweets_volume = []

for date in dates:
    temp = df_tweets[df_tweets['date'] == date]
    avg_sentiment.append(temp['sentiment_score'].mean())
    tweets_volume.append(len(temp))
  
df_tweet_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_tweets':avg_sentiment, '# tweets' : tweets_volume})

# %%
df_news['Sentiment'] = df_news['Sentiment'].map({'positive': 1, 'neutral': 0, 'negative': -1})

dates = df_news['Date'].unique()
avg_sentiment = []
pos_count = []
neu_count = []
neg_count = []


for date in dates:
    temp = df_news[df_news['Date'] == date]
    avg_sentiment.append(temp['Sentiment'].mean())
    pos_count.append(len(temp[temp['Sentiment'] == 1]))
    neu_count.append(len(temp[temp['Sentiment'] == 0]))
    neg_count.append(len(temp[temp['Sentiment'] == -1]))

df_news_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_news':avg_sentiment, '# Positive news' : pos_count, 
                               '# Neutral news' : neu_count, '# Negative news' : neg_count})

# %%
df_political_news['Sentiment'] = df_political_news['Sentiment'].map({'Positive': 1, 'Neutral': 0, 'Negative': -1})

dates = df_political_news['Date'].unique()
avg_sentiment = []
pos_count = []
neu_count = []
neg_count = []


for date in dates:
    temp = df_political_news[df_political_news['Date'] == date]
    avg_sentiment.append(temp['Sentiment'].mean())
    pos_count.append(len(temp[temp['Sentiment'] == 1]))
    neu_count.append(len(temp[temp['Sentiment'] == 0]))
    neg_count.append(len(temp[temp['Sentiment'] == -1]))

df_political_news_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_polit_news':avg_sentiment, '# Positive polit_news' : pos_count, 
                               '# Neutral polit_news' : neu_count, '# Negative polit_news' : neg_count})

# %%
stock = yf.Ticker(company_ticker)

start = min(df_tweet_scores['Date'])
end = max(df_tweet_scores['Date'])

df = stock.history(start=pd.to_datetime(start).date(), end=pd.to_datetime(end).date())

# %%
df['Close'].plot(figsize=(6,3))

# %%
df = df.reset_index()[['Date', 'Close']]
df['Date'] = df['Date'].apply(lambda x: datetime.strftime(pd.to_datetime(x), '%Y-%m-%d'))

df = pd.merge(df,df_tweet_scores,on='Date',how='inner')
df = pd.merge(df,df_news_scores,on='Date',how='inner')
df = pd.merge(df,df_political_news_scores,on='Date',how='left')

# %%
df.fillna(df.mean(), inplace=True)

# %%
def processData(data,lb):
    X,Y = [],[]
    data = data.to_numpy()
    for i in range(len(data)-lb-1):
        X.append(data[i:(i+lb),0])
        Y.append(data[(i+lb),0])
    return np.array(X),np.array(Y)

# %%
def processMultiData(data,lb):
    X,Y = [],[]
    df_as_np = data.to_numpy()
    for i in range(len(data)-lb-1):
        row = [r for r in df_as_np[i:i+lb]]
        X.append(row)
        Y.append(df_as_np[i+lb][0])
    return np.array(X),np.array(Y)

# %%
def train_test_data(feature_vector):
  lb=10
  train_size = 0.80

  data = df[feature_vector]
  scl = MinMaxScaler()
  multi_data = data.copy()
  train_data = data[0:int(len(df[['Close']])*0.80)]
  scl.fit(train_data)
  multi_data[feature_vector] = scl.transform(multi_data[feature_vector])

  if len(feature_vector) == 1:
    X,y = processData(multi_data,lb)
  else:
    X,y = processMultiData(multi_data,lb)

  X_train,X_test = X[:int(X.shape[0]*train_size)],X[int(X.shape[0]*train_size):]
  y_train,y_test = y[:int(y.shape[0]*train_size)],y[int(y.shape[0]*train_size):]  

  return X_train, X_test, y_train, y_test, scl

# %%
def create_model(X_train, y_train, feature_number, lb=10):
    tf.keras.backend.clear_session()
    tf.random.set_seed(51)
    np.random.seed(51)

    model = Sequential()

    model.add(LSTM(units=128, dropout=0.2, recurrent_dropout=0.2, 
                   return_sequences=True, input_shape=(lb, feature_number)))
    model.add(LSTM(units=64, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
    model.add(LSTM(units=32, dropout=0.2, recurrent_dropout=0.2))

    model.add(Dense(units=16))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mse')

    earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                            patience=25, restore_best_weights=True)
    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], feature_number))

    history = model.fit(X_train, y_train, epochs=300, validation_split=0.2,
                        shuffle=False, callbacks=[earlystopping])
    
    tf.keras.utils.plot_model(model, to_file='model_architecture_lstm.png', show_shapes=True)

    return model

# %%
def make_predictions(X_test, y_test, model, feature_vector, scl):
  Xt = model.predict(X_test)
  Xt = Xt.flatten()
  some_features_actual = {"Actual":y_test}
  some_features_predicted = {"Predicted":Xt}

  for i in range(len(feature_vector) - 1):
    some_features_actual["null_val" + str(i)] = [0]* len(y_test)
    some_features_predicted["null_val" + str(i)] = [0]* len(Xt)
  
  df_actual = pd.DataFrame(some_features_actual)
  df_actual[list(some_features_actual.keys())] = scl.inverse_transform(df_actual[list(some_features_actual.keys())])

  df_predicted = pd.DataFrame(some_features_predicted)
  df_predicted[list(some_features_predicted.keys())] = scl.inverse_transform(df_predicted[list(some_features_predicted.keys())])

  test_rmse = math.sqrt(mean_squared_error(df_actual.Actual,df_predicted.Predicted))
  test_mae = mean_absolute_error(df_actual.Actual,df_predicted.Predicted) 


  y_pred_diff = [list(df_predicted.Predicted)[i] - list(df_predicted.Predicted)[i-1] for i in range(1, len(list(df_predicted.Predicted)))]
  y_test_diff = [list(df_actual.Actual)[i] - list(df_actual.Actual)[i-1] for i in range(1, len(list(df_actual.Actual)))]

  y_pred_movement = [1 if diff > 0 else 0 for diff in y_pred_diff]
  y_test_movement = [1 if diff > 0 else 0 for diff in y_test_diff]

  accuracy = sum([1 for pred, actual in zip(y_pred_movement, y_test_movement) if pred == actual]) / len(y_test_movement)

  return test_rmse, test_mae, accuracy, list(df_predicted.Predicted)

# %%
#Wilcoxon Signed Rank Test

def wilcoxon_signed_rank_test(arr1, arr2, metric):
  if metric != 'accuracy':
    statistic, p_value = wilcoxon(arr1, arr2, alternative='greater')
  else:
    statistic, p_value = wilcoxon(arr1, arr2, alternative='less')
  alpha = 0.05
  if p_value < alpha:
    return False #there is a difference
  return True #no difference

# %%
#Mann-Whitney U test

def mannwhitneyu_test(arr1, arr2, metric):
  if metric != 'accuracy':
    statistic, p_value = mannwhitneyu(arr1, arr2, alternative='greater')
  else:
    statistic, p_value = mannwhitneyu(arr1, arr2, alternative='less')
  alpha = 0.05
  if p_value < alpha:
    return False #there is a difference
  return True #no difference

# %%
model_results = {
    'Prices' : [['Close'], [], [], []],
    'Prices + Tweets' : [['Close', 'Avg_sentiment_tweets'], [], [], []],
    'Prices + News' : [['Close', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news'], [], [], []],
    'Prices + Political News' : [['Close', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + Tweets + News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news'], [], [], []],
    'Prices + Tweets + Political News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + News + Political News' : [['Close', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + Tweets + News + Political News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []]
}

# %%
test_results = {
    'RMSE Wilcoxon' : [],
    'MAE Wilcoxon' : [],
    'Accuracy Wilcoxon' : [],
    'RMSE Mann-Whitney' : [],
    'MAE Mann-Whitney' : [],
    'Accuracy Mann-Whitney' : []
}

# %%
for i in range(10):
  for key, item in model_results.items():
    feature_vector = model_results[key][0]
    X_train, X_test, y_train, y_test, scl = train_test_data(feature_vector)
    model = create_model(X_train, y_train, len(feature_vector))
    test_rmse, test_mae, accuracy, predicted_values = make_predictions(X_test, y_test, model, feature_vector, scl)
    model_results[key][1].append(round(test_rmse, 2))
    model_results[key][2].append(round(test_mae, 2))
    model_results[key][3].append(round(accuracy, 2))
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 21/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0046 - val_loss: 0.0180
# Epoch 22/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0050 - val_loss: 0.0225
# Epoch 23/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0034 - val_loss: 0.0218
# Epoch 24/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0049 - val_loss: 0.0056
# Epoch 25/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0054 - val_loss: 0.0085
# Epoch 26/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0044 - val_loss: 0.0064
# Epoch 27/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0049 - val_loss: 0.0083
# Epoch 28/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0042 - val_loss: 0.0091
# Epoch 29/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0039 - val_loss: 0.0107
# Epoch 30/300
# 24/24 [==============================] - 4s 166ms/step - loss: 0.0039 - val_loss: 0.0145
# Epoch 31/300
# 24/24 [==============================] - 3s 137ms/step - loss: 0.0039 - val_loss: 0.0142
# Epoch 32/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0037 - val_loss: 0.0147
# 8/8 [==============================] - 1s 15ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 104ms/step - loss: 0.0324 - val_loss: 0.0088
# Epoch 2/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0649 - val_loss: 0.1391
# Epoch 3/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0346 - val_loss: 0.0684
# Epoch 4/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0139 - val_loss: 0.0048
# Epoch 5/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0035 - val_loss: 0.0091
# Epoch 6/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0047 - val_loss: 0.0069
# Epoch 7/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0054 - val_loss: 0.0100
# Epoch 8/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0057 - val_loss: 0.0070
# Epoch 9/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0054 - val_loss: 0.0078
# Epoch 10/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0055 - val_loss: 0.0061
# Epoch 11/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 12/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0060 - val_loss: 0.0059
# Epoch 13/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0048 - val_loss: 0.0114
# Epoch 14/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0053 - val_loss: 0.0061
# Epoch 15/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 16/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0050 - val_loss: 0.0062
# Epoch 17/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0041 - val_loss: 0.0114
# Epoch 18/300
# 24/24 [==============================] - 2s 105ms/step - loss: 0.0049 - val_loss: 0.0092
# Epoch 19/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0048 - val_loss: 0.0112
# Epoch 20/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0044 - val_loss: 0.0102
# Epoch 21/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0040 - val_loss: 0.0118
# Epoch 22/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0044 - val_loss: 0.0131
# Epoch 23/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0043 - val_loss: 0.0185
# Epoch 24/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0042 - val_loss: 0.0240
# Epoch 25/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0031 - val_loss: 0.0262
# Epoch 26/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0034 - val_loss: 0.0170
# Epoch 27/300
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0044 - val_loss: 0.0260
# Epoch 28/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0034 - val_loss: 0.0237
# Epoch 29/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0040 - val_loss: 0.0191
# 8/8 [==============================] - 1s 10ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 100ms/step - loss: 0.0312 - val_loss: 0.0119
# Epoch 2/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0575 - val_loss: 0.0971
# Epoch 3/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0250 - val_loss: 0.0051
# Epoch 4/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0094 - val_loss: 0.0189
# Epoch 5/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0056 - val_loss: 0.0090
# Epoch 6/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0081 - val_loss: 0.0055
# Epoch 7/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0032 - val_loss: 0.0085
# Epoch 8/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 9/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0047 - val_loss: 0.0067
# Epoch 10/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 11/300
# 24/24 [==============================] - 1s 63ms/step - loss: 0.0070 - val_loss: 0.0055
# Epoch 12/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0053 - val_loss: 0.0054
# Epoch 13/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0048 - val_loss: 0.0076
# Epoch 14/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0047 - val_loss: 0.0056
# Epoch 15/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 16/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 17/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0043 - val_loss: 0.0076
# Epoch 18/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 19/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0049 - val_loss: 0.0069
# Epoch 20/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0050 - val_loss: 0.0055
# Epoch 21/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0042 - val_loss: 0.0066
# Epoch 22/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0046 - val_loss: 0.0068
# Epoch 23/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0044 - val_loss: 0.0078
# Epoch 24/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0049 - val_loss: 0.0085
# Epoch 25/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0039 - val_loss: 0.0105
# Epoch 26/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0036 - val_loss: 0.0117
# Epoch 27/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0048 - val_loss: 0.0122
# Epoch 28/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0045 - val_loss: 0.0151
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 102ms/step - loss: 0.0286 - val_loss: 0.0140
# Epoch 2/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0821 - val_loss: 0.1936
# Epoch 3/300
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0475 - val_loss: 0.1576
# Epoch 4/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0265 - val_loss: 0.0572
# Epoch 5/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0108 - val_loss: 0.0043
# Epoch 6/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0053 - val_loss: 0.0095
# Epoch 7/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0075 - val_loss: 0.0078
# Epoch 8/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0090 - val_loss: 0.0063
# Epoch 9/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0079 - val_loss: 0.0058
# Epoch 10/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0061 - val_loss: 0.0074
# Epoch 11/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0051 - val_loss: 0.0091
# Epoch 12/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0052 - val_loss: 0.0106
# Epoch 13/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0050 - val_loss: 0.0122
# Epoch 14/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0056 - val_loss: 0.0144
# Epoch 15/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0056 - val_loss: 0.0166
# Epoch 16/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0051 - val_loss: 0.0244
# Epoch 17/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0047 - val_loss: 0.0275
# Epoch 18/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0039 - val_loss: 0.0335
# Epoch 19/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0054 - val_loss: 0.0401
# Epoch 20/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0067 - val_loss: 0.0377
# Epoch 21/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0045 - val_loss: 0.0335
# Epoch 22/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0055 - val_loss: 0.0107
# Epoch 23/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0077 - val_loss: 0.0084
# Epoch 24/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0067 - val_loss: 0.0074
# Epoch 25/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0058 - val_loss: 0.0084
# Epoch 26/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0042 - val_loss: 0.0171
# Epoch 27/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0038 - val_loss: 0.0168
# Epoch 28/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0043 - val_loss: 0.0186
# Epoch 29/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0042 - val_loss: 0.0219
# Epoch 30/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0040 - val_loss: 0.0267
# 8/8 [==============================] - 1s 10ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 141ms/step - loss: 0.0384 - val_loss: 0.0145
# Epoch 2/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0781 - val_loss: 0.2277
# Epoch 3/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0419 - val_loss: 0.1567
# Epoch 4/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0264 - val_loss: 0.0577
# Epoch 5/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0093 - val_loss: 0.0131
# Epoch 6/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0060 - val_loss: 0.0142
# Epoch 7/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0095 - val_loss: 0.0109
# Epoch 8/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0108 - val_loss: 0.0121
# Epoch 9/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0076 - val_loss: 0.0108
# Epoch 10/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0049 - val_loss: 0.0110
# Epoch 11/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0057 - val_loss: 0.0118
# Epoch 12/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0061 - val_loss: 0.0116
# Epoch 13/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0063 - val_loss: 0.0118
# Epoch 14/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0052 - val_loss: 0.0101
# Epoch 15/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0061 - val_loss: 0.0116
# Epoch 16/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0053 - val_loss: 0.0112
# Epoch 17/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0044 - val_loss: 0.0127
# Epoch 18/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0046 - val_loss: 0.0139
# Epoch 19/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0055 - val_loss: 0.0134
# Epoch 20/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0052 - val_loss: 0.0142
# Epoch 21/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0047 - val_loss: 0.0172
# Epoch 22/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0044 - val_loss: 0.0199
# Epoch 23/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0041 - val_loss: 0.0262
# Epoch 24/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0036 - val_loss: 0.0274
# Epoch 25/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0032 - val_loss: 0.0320
# Epoch 26/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0038 - val_loss: 0.0371
# Epoch 27/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0038 - val_loss: 0.0346
# Epoch 28/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0040 - val_loss: 0.0368
# Epoch 29/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0046 - val_loss: 0.0318
# Epoch 30/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0037 - val_loss: 0.0395
# Epoch 31/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0049 - val_loss: 0.0155
# Epoch 32/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0066 - val_loss: 0.0145
# Epoch 33/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0043 - val_loss: 0.0314
# Epoch 34/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0037 - val_loss: 0.0306
# Epoch 35/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0041 - val_loss: 0.0337
# Epoch 36/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0030 - val_loss: 0.0292
# Epoch 37/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0030 - val_loss: 0.0433
# Epoch 38/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0040 - val_loss: 0.0297
# Epoch 39/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0040 - val_loss: 0.0253
# 8/8 [==============================] - 1s 17ms/step
# Epoch 1/300
# 24/24 [==============================] - 11s 121ms/step - loss: 0.0166 - val_loss: 0.0177
# Epoch 2/300
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0232 - val_loss: 0.0198
# Epoch 3/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0169 - val_loss: 0.0126
# Epoch 4/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 5/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0036 - val_loss: 0.0060
# Epoch 6/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0031 - val_loss: 0.0049
# Epoch 7/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0047 - val_loss: 0.0048
# Epoch 8/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0046 - val_loss: 0.0049
# Epoch 9/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0047 - val_loss: 0.0051
# Epoch 10/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0052 - val_loss: 0.0050
# Epoch 11/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0041 - val_loss: 0.0056
# Epoch 12/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0041 - val_loss: 0.0050
# Epoch 13/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0042 - val_loss: 0.0059
# Epoch 14/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 15/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0046 - val_loss: 0.0052
# Epoch 16/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0047 - val_loss: 0.0055
# Epoch 17/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0048 - val_loss: 0.0055
# Epoch 18/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0034 - val_loss: 0.0067
# Epoch 19/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0038 - val_loss: 0.0058
# Epoch 20/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0044 - val_loss: 0.0066
# Epoch 21/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0049 - val_loss: 0.0073
# Epoch 22/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0043 - val_loss: 0.0101
# Epoch 23/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0043 - val_loss: 0.0091
# Epoch 24/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 25/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0033 - val_loss: 0.0107
# Epoch 26/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0041 - val_loss: 0.0124
# Epoch 27/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0038 - val_loss: 0.0106
# Epoch 28/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0033 - val_loss: 0.0164
# Epoch 29/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0032 - val_loss: 0.0191
# 8/8 [==============================] - 1s 11ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 120ms/step - loss: 0.0224 - val_loss: 0.0229
# Epoch 2/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0363 - val_loss: 0.0426
# Epoch 3/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0144 - val_loss: 0.0093
# Epoch 4/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0042 - val_loss: 0.0056
# Epoch 5/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0037 - val_loss: 0.0054
# Epoch 6/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 7/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0043 - val_loss: 0.0056
# Epoch 8/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0051 - val_loss: 0.0057
# Epoch 9/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0046 - val_loss: 0.0059
# Epoch 10/300
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0049 - val_loss: 0.0062
# Epoch 11/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0051 - val_loss: 0.0058
# Epoch 12/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0053 - val_loss: 0.0060
# Epoch 13/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 14/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0041 - val_loss: 0.0082
# Epoch 15/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0032 - val_loss: 0.0075
# Epoch 16/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0039 - val_loss: 0.0073
# Epoch 17/300
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0057 - val_loss: 0.0067
# Epoch 18/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0050 - val_loss: 0.0077
# Epoch 19/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0056 - val_loss: 0.0043
# Epoch 20/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0029 - val_loss: 0.0080
# Epoch 21/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0032 - val_loss: 0.0117
# Epoch 22/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0028 - val_loss: 0.0101
# Epoch 23/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0041 - val_loss: 0.0075
# Epoch 24/300
# 24/24 [==============================] - 3s 134ms/step - loss: 0.0042 - val_loss: 0.0099
# Epoch 25/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0035 - val_loss: 0.0107
# Epoch 26/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0028 - val_loss: 0.0115
# Epoch 27/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0039 - val_loss: 0.0105
# Epoch 28/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0036 - val_loss: 0.0142
# Epoch 29/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0034 - val_loss: 0.0174
# Epoch 30/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0029 - val_loss: 0.0204
# Epoch 31/300
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0034 - val_loss: 0.0218
# Epoch 32/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0045 - val_loss: 0.0160
# Epoch 33/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0032 - val_loss: 0.0317
# Epoch 34/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0026 - val_loss: 0.0209
# Epoch 35/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0041 - val_loss: 0.0062
# Epoch 36/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0050 - val_loss: 0.0061
# Epoch 37/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0037 - val_loss: 0.0164
# Epoch 38/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0036 - val_loss: 0.0203
# Epoch 39/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0034 - val_loss: 0.0218
# Epoch 40/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0041 - val_loss: 0.0203
# Epoch 41/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0029 - val_loss: 0.0208
# Epoch 42/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0030 - val_loss: 0.0291
# Epoch 43/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0034 - val_loss: 0.0251
# Epoch 44/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0026 - val_loss: 0.0239
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 108ms/step - loss: 0.0442 - val_loss: 0.0588
# Epoch 2/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0533 - val_loss: 0.1270
# Epoch 3/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0255 - val_loss: 0.0190
# Epoch 4/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0110 - val_loss: 0.0069
# Epoch 5/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0059 - val_loss: 0.0078
# Epoch 6/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0075 - val_loss: 0.0083
# Epoch 7/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0047 - val_loss: 0.0062
# Epoch 8/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0053 - val_loss: 0.0083
# Epoch 9/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0045 - val_loss: 0.0082
# Epoch 10/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0044 - val_loss: 0.0080
# Epoch 11/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0047 - val_loss: 0.0081
# Epoch 12/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0055 - val_loss: 0.0079
# Epoch 13/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0062 - val_loss: 0.0099
# Epoch 14/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0064 - val_loss: 0.0106
# Epoch 15/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0055 - val_loss: 0.0131
# Epoch 16/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0039 - val_loss: 0.0268
# Epoch 17/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0045 - val_loss: 0.0198
# Epoch 18/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0037 - val_loss: 0.0241
# Epoch 19/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0034 - val_loss: 0.0277
# Epoch 20/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0040 - val_loss: 0.0236
# Epoch 21/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0045 - val_loss: 0.0262
# Epoch 22/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0043 - val_loss: 0.0281
# Epoch 23/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0050 - val_loss: 0.0088
# Epoch 24/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0046 - val_loss: 0.0065
# Epoch 25/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0041 - val_loss: 0.0126
# Epoch 26/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0044 - val_loss: 0.0183
# Epoch 27/300
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0036 - val_loss: 0.0203
# Epoch 28/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0036 - val_loss: 0.0258
# Epoch 29/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0036 - val_loss: 0.0261
# Epoch 30/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0040 - val_loss: 0.0278
# Epoch 31/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0043 - val_loss: 0.0284
# Epoch 32/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0034 - val_loss: 0.0364
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 15s 123ms/step - loss: 0.0457 - val_loss: 0.0685
# Epoch 2/300
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0498 - val_loss: 0.1211
# Epoch 3/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0220 - val_loss: 0.0070
# Epoch 4/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0098 - val_loss: 0.0050
# Epoch 5/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0051 - val_loss: 0.0050
# Epoch 6/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0055 - val_loss: 0.0080
# Epoch 7/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 8/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0052 - val_loss: 0.0056
# Epoch 9/300
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0052 - val_loss: 0.0061
# Epoch 10/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0064
# Epoch 11/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0058 - val_loss: 0.0057
# Epoch 12/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0059 - val_loss: 0.0059
# Epoch 13/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0057 - val_loss: 0.0083
# Epoch 14/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0061 - val_loss: 0.0070
# Epoch 15/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 16/300
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0038 - val_loss: 0.0160
# Epoch 17/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0043 - val_loss: 0.0195
# Epoch 18/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0047 - val_loss: 0.0107
# Epoch 19/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0045 - val_loss: 0.0097
# Epoch 20/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0034 - val_loss: 0.0140
# Epoch 21/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0046 - val_loss: 0.0159
# Epoch 22/300
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0047 - val_loss: 0.0165
# Epoch 23/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0035 - val_loss: 0.0329
# Epoch 24/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0048 - val_loss: 0.0162
# Epoch 25/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0039 - val_loss: 0.0129
# Epoch 26/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0033 - val_loss: 0.0143
# Epoch 27/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0040 - val_loss: 0.0197
# Epoch 28/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0039 - val_loss: 0.0221
# Epoch 29/300
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0038 - val_loss: 0.0241
# Epoch 30/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0048 - val_loss: 0.0193
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 127ms/step - loss: 0.0462 - val_loss: 0.0513
# Epoch 2/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0530 - val_loss: 0.1316
# Epoch 3/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0174 - val_loss: 0.0064
# Epoch 4/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0086 - val_loss: 0.0223
# Epoch 5/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0072 - val_loss: 0.0131
# Epoch 6/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0094 - val_loss: 0.0070
# Epoch 7/300
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0042 - val_loss: 0.0100
# Epoch 8/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0057 - val_loss: 0.0087
# Epoch 9/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0048 - val_loss: 0.0090
# Epoch 10/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0056 - val_loss: 0.0084
# Epoch 11/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0069 - val_loss: 0.0090
# Epoch 12/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0062 - val_loss: 0.0086
# Epoch 13/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0048 - val_loss: 0.0130
# Epoch 14/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0049 - val_loss: 0.0110
# Epoch 15/300
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0053 - val_loss: 0.0124
# Epoch 16/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0043 - val_loss: 0.0115
# Epoch 17/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0038 - val_loss: 0.0154
# Epoch 18/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0047 - val_loss: 0.0144
# Epoch 19/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0049 - val_loss: 0.0159
# Epoch 20/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0044 - val_loss: 0.0172
# Epoch 21/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0040 - val_loss: 0.0189
# Epoch 22/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0042 - val_loss: 0.0282
# Epoch 23/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0041 - val_loss: 0.0272
# Epoch 24/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0036 - val_loss: 0.0308
# Epoch 25/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0040 - val_loss: 0.0257
# Epoch 26/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0034 - val_loss: 0.0215
# Epoch 27/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0041 - val_loss: 0.0348
# Epoch 28/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0043 - val_loss: 0.0326
# 8/8 [==============================] - 1s 17ms/step
# Epoch 1/300
# 24/24 [==============================] - 15s 174ms/step - loss: 0.0455 - val_loss: 0.0490
# Epoch 2/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0498 - val_loss: 0.1025
# Epoch 3/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0183 - val_loss: 0.0050
# Epoch 4/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0075 - val_loss: 0.0165
# Epoch 5/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 6/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0071 - val_loss: 0.0069
# Epoch 7/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0041 - val_loss: 0.0080
# Epoch 8/300
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0055 - val_loss: 0.0075
# Epoch 9/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0054 - val_loss: 0.0073
# Epoch 10/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0058 - val_loss: 0.0068
# Epoch 11/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0069 - val_loss: 0.0066
# Epoch 12/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0062 - val_loss: 0.0073
# Epoch 13/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0050 - val_loss: 0.0082
# Epoch 14/300
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0045 - val_loss: 0.0090
# Epoch 15/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0047 - val_loss: 0.0106
# Epoch 16/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0043 - val_loss: 0.0101
# Epoch 17/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0039 - val_loss: 0.0147
# Epoch 18/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0046 - val_loss: 0.0143
# Epoch 19/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0053 - val_loss: 0.0171
# Epoch 20/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0043 - val_loss: 0.0205
# Epoch 21/300
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0040 - val_loss: 0.0242
# Epoch 22/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0037 - val_loss: 0.0263
# Epoch 23/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0044 - val_loss: 0.0172
# Epoch 24/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0043 - val_loss: 0.0158
# Epoch 25/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0033 - val_loss: 0.0275
# Epoch 26/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0043 - val_loss: 0.0173
# Epoch 27/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0056 - val_loss: 0.0214
# Epoch 28/300
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0035 - val_loss: 0.0327
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 162ms/step - loss: 0.0490 - val_loss: 0.0672
# Epoch 2/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0651 - val_loss: 0.2232
# Epoch 3/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0301 - val_loss: 0.0942
# Epoch 4/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0241 - val_loss: 0.0161
# Epoch 5/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0097 - val_loss: 0.0074
# Epoch 6/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0051 - val_loss: 0.0079
# Epoch 7/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0068 - val_loss: 0.0063
# Epoch 8/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 9/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 10/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0064 - val_loss: 0.0071
# Epoch 11/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0060 - val_loss: 0.0080
# Epoch 12/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0060 - val_loss: 0.0081
# Epoch 13/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0052 - val_loss: 0.0114
# Epoch 14/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0060 - val_loss: 0.0121
# Epoch 15/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0062 - val_loss: 0.0138
# Epoch 16/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0055 - val_loss: 0.0175
# Epoch 17/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0049 - val_loss: 0.0202
# Epoch 18/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0046 - val_loss: 0.0182
# Epoch 19/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0056 - val_loss: 0.0286
# Epoch 20/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0057 - val_loss: 0.0289
# Epoch 21/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0038 - val_loss: 0.0250
# Epoch 22/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0055 - val_loss: 0.0127
# Epoch 23/300
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0063 - val_loss: 0.0087
# Epoch 24/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0061 - val_loss: 0.0145
# Epoch 25/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0051 - val_loss: 0.0164
# Epoch 26/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0036 - val_loss: 0.0278
# Epoch 27/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0032 - val_loss: 0.0242
# Epoch 28/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0038 - val_loss: 0.0246
# Epoch 29/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0036 - val_loss: 0.0281
# Epoch 30/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0034 - val_loss: 0.0313
# Epoch 31/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0044 - val_loss: 0.0129
# Epoch 32/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0047 - val_loss: 0.0109
# Epoch 33/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0040 - val_loss: 0.0246
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 119ms/step - loss: 0.0479 - val_loss: 0.0625
# Epoch 2/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0616 - val_loss: 0.1752
# Epoch 3/300
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0340 - val_loss: 0.0908
# Epoch 4/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0149 - val_loss: 0.0063
# Epoch 5/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0052 - val_loss: 0.0120
# Epoch 6/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0058 - val_loss: 0.0083
# Epoch 7/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0088 - val_loss: 0.0089
# Epoch 8/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0098 - val_loss: 0.0075
# Epoch 9/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0070 - val_loss: 0.0097
# Epoch 10/300
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0051 - val_loss: 0.0082
# Epoch 11/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0059 - val_loss: 0.0108
# Epoch 12/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0068 - val_loss: 0.0111
# Epoch 13/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0065 - val_loss: 0.0115
# Epoch 14/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0055 - val_loss: 0.0102
# Epoch 15/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0061 - val_loss: 0.0127
# Epoch 16/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0051 - val_loss: 0.0145
# Epoch 17/300
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0043 - val_loss: 0.0177
# Epoch 18/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0047 - val_loss: 0.0183
# Epoch 19/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0054 - val_loss: 0.0197
# Epoch 20/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0051 - val_loss: 0.0248
# Epoch 21/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0052 - val_loss: 0.0269
# Epoch 22/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0042 - val_loss: 0.0255
# Epoch 23/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0054 - val_loss: 0.0139
# Epoch 24/300
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0053 - val_loss: 0.0104
# Epoch 25/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0038 - val_loss: 0.0223
# Epoch 26/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0031 - val_loss: 0.0299
# Epoch 27/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0036 - val_loss: 0.0274
# Epoch 28/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0037 - val_loss: 0.0250
# Epoch 29/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0040 - val_loss: 0.0283
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 15s 120ms/step - loss: 0.0196 - val_loss: 0.0233
# Epoch 2/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0331 - val_loss: 0.0601
# Epoch 3/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0133 - val_loss: 0.0104
# Epoch 4/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0042 - val_loss: 0.0103
# Epoch 5/300
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0040 - val_loss: 0.0050
# Epoch 6/300
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0040 - val_loss: 0.0056
# Epoch 7/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0054 - val_loss: 0.0061
# Epoch 8/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0055 - val_loss: 0.0059
# Epoch 9/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0054 - val_loss: 0.0059
# Epoch 10/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0049 - val_loss: 0.0054
# Epoch 11/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0039 - val_loss: 0.0068
# Epoch 12/300
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0039 - val_loss: 0.0054
# Epoch 13/300
# 24/24 [==============================] - 3s 102ms/step - loss: 0.0042 - val_loss: 0.0077
# Epoch 14/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0041 - val_loss: 0.0047
# Epoch 15/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0042 - val_loss: 0.0051
# Epoch 16/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0041 - val_loss: 0.0060
# Epoch 17/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0041 - val_loss: 0.0069
# Epoch 18/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0036 - val_loss: 0.0080
# Epoch 19/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0041 - val_loss: 0.0075
# Epoch 20/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0044 - val_loss: 0.0106
# Epoch 21/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0049 - val_loss: 0.0120
# Epoch 22/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0047 - val_loss: 0.0143
# Epoch 23/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0048 - val_loss: 0.0097
# Epoch 24/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0036 - val_loss: 0.0170
# Epoch 25/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0033 - val_loss: 0.0207
# Epoch 26/300
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0045 - val_loss: 0.0056
# Epoch 27/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0045 - val_loss: 0.0053
# Epoch 28/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0036 - val_loss: 0.0072
# Epoch 29/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0036 - val_loss: 0.0107
# Epoch 30/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0041 - val_loss: 0.0135
# Epoch 31/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0047 - val_loss: 0.0101
# Epoch 32/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0033 - val_loss: 0.0174
# Epoch 33/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0033 - val_loss: 0.0206
# Epoch 34/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0033 - val_loss: 0.0228
# Epoch 35/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0034 - val_loss: 0.0207
# Epoch 36/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0034 - val_loss: 0.0256
# Epoch 37/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0043 - val_loss: 0.0227
# Epoch 38/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0032 - val_loss: 0.0188
# Epoch 39/300
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0024 - val_loss: 0.0265
# 8/8 [==============================] - 1s 15ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 115ms/step - loss: 0.0233 - val_loss: 0.0254
# Epoch 2/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0359 - val_loss: 0.0326
# Epoch 3/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0155 - val_loss: 0.0090
# Epoch 4/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0051 - val_loss: 0.0066
# Epoch 5/300
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0031 - val_loss: 0.0060
# Epoch 6/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0035 - val_loss: 0.0066
# Epoch 7/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0036 - val_loss: 0.0057
# Epoch 8/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0050 - val_loss: 0.0060
# Epoch 9/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0048 - val_loss: 0.0057
# Epoch 10/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0050 - val_loss: 0.0072
# Epoch 11/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0051 - val_loss: 0.0053
# Epoch 12/300
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0047 - val_loss: 0.0069
# Epoch 13/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0048 - val_loss: 0.0052
# Epoch 14/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0038 - val_loss: 0.0079
# Epoch 15/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0033 - val_loss: 0.0109
# Epoch 16/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0040 - val_loss: 0.0090
# Epoch 17/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0056 - val_loss: 0.0078
# Epoch 18/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0053 - val_loss: 0.0075
# Epoch 19/300
# 24/24 [==============================] - 3s 124ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 20/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0029 - val_loss: 0.0086
# Epoch 21/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0033 - val_loss: 0.0154
# Epoch 22/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0028 - val_loss: 0.0182
# Epoch 23/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0040 - val_loss: 0.0172
# Epoch 24/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0045 - val_loss: 0.0211
# Epoch 25/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0048 - val_loss: 0.0165
# Epoch 26/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0032 - val_loss: 0.0279
# Epoch 27/300
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0036 - val_loss: 0.0325
# Epoch 28/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0037 - val_loss: 0.0309
# Epoch 29/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0029 - val_loss: 0.0455
# Epoch 30/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0032 - val_loss: 0.0261
# Epoch 31/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0030 - val_loss: 0.0394
# Epoch 32/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0029 - val_loss: 0.0242
# Epoch 33/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0041 - val_loss: 0.0070
# Epoch 34/300
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0059 - val_loss: 0.0161
# Epoch 35/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0031 - val_loss: 0.0288
# Epoch 36/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0043 - val_loss: 0.0085
# Epoch 37/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0053 - val_loss: 0.0102
# Epoch 38/300
# ...
# Epoch 18/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0050 - val_loss: 0.0071
# Epoch 19/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0046 - val_loss: 0.0089
# Epoch 20/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0039 - val_loss: 0.0135
# Epoch 21/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0047 - val_loss: 0.0127
# Epoch 22/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0049 - val_loss: 0.0128
# Epoch 23/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0032 - val_loss: 0.0245
# Epoch 24/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0043 - val_loss: 0.0243
# Epoch 25/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0039 - val_loss: 0.0180
# Epoch 26/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0033 - val_loss: 0.0255
# Epoch 27/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0040 - val_loss: 0.0252
# Epoch 28/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0041 - val_loss: 0.0184
# 8/8 [==============================] - 1s 15ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 136ms/step - loss: 0.0433 - val_loss: 0.0395
# Epoch 2/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0588 - val_loss: 0.1487
# Epoch 3/300
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0288 - val_loss: 0.0352
# Epoch 4/300
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0129 - val_loss: 0.0068
# Epoch 5/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0049 - val_loss: 0.0108
# Epoch 6/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0058 - val_loss: 0.0113
# Epoch 7/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0047 - val_loss: 0.0091
# Epoch 8/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0057 - val_loss: 0.0093
# Epoch 9/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0056 - val_loss: 0.0077
# Epoch 10/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0058 - val_loss: 0.0088
# Epoch 11/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0066 - val_loss: 0.0084
# Epoch 12/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0064 - val_loss: 0.0095
# Epoch 13/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0050 - val_loss: 0.0124
# Epoch 14/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0047 - val_loss: 0.0117
# Epoch 15/300
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0047 - val_loss: 0.0145
# Epoch 16/300
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 17/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0038 - val_loss: 0.0177
# Epoch 18/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0042 - val_loss: 0.0204
# Epoch 19/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0047 - val_loss: 0.0229
# Epoch 20/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0041 - val_loss: 0.0231
# Epoch 21/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0046 - val_loss: 0.0216
# Epoch 22/300
# 24/24 [==============================] - 3s 131ms/step - loss: 0.0049 - val_loss: 0.0306
# Epoch 23/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0036 - val_loss: 0.0300
# Epoch 24/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0049 - val_loss: 0.0142
# Epoch 25/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0070 - val_loss: 0.0060
# Epoch 26/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0051 - val_loss: 0.0100
# Epoch 27/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0053 - val_loss: 0.0102
# Epoch 28/300
# 24/24 [==============================] - 3s 132ms/step - loss: 0.0040 - val_loss: 0.0165
# Epoch 29/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0037 - val_loss: 0.0153
# Epoch 30/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0036 - val_loss: 0.0198
# Epoch 31/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0034 - val_loss: 0.0194
# Epoch 32/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0030 - val_loss: 0.0282
# Epoch 33/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0032 - val_loss: 0.0197
# Epoch 34/300
# 24/24 [==============================] - 3s 130ms/step - loss: 0.0036 - val_loss: 0.0225
# Epoch 35/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0043 - val_loss: 0.0195
# Epoch 36/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0038 - val_loss: 0.0271
# Epoch 37/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0026 - val_loss: 0.0336
# Epoch 38/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0029 - val_loss: 0.0231
# Epoch 39/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0030 - val_loss: 0.0254
# Epoch 40/300
# 24/24 [==============================] - 3s 136ms/step - loss: 0.0031 - val_loss: 0.0317
# Epoch 41/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0042 - val_loss: 0.0200
# Epoch 42/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0048 - val_loss: 0.0268
# Epoch 43/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0035 - val_loss: 0.0385
# Epoch 44/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0042 - val_loss: 0.0179
# Epoch 45/300
# 24/24 [==============================] - 3s 123ms/step - loss: 0.0039 - val_loss: 0.0187
# Epoch 46/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0035 - val_loss: 0.0316
# Epoch 47/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0033 - val_loss: 0.0308
# Epoch 48/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0022 - val_loss: 0.0340
# Epoch 49/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0024 - val_loss: 0.0339
# Epoch 50/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0031 - val_loss: 0.0309
# 8/8 [==============================] - 1s 19ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 137ms/step - loss: 0.0403 - val_loss: 0.0155
# Epoch 2/300
# 24/24 [==============================] - 3s 122ms/step - loss: 0.0536 - val_loss: 0.1051
# Epoch 3/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0309 - val_loss: 0.0327
# Epoch 4/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0102 - val_loss: 0.0100
# Epoch 5/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0039 - val_loss: 0.0082
# Epoch 6/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0069 - val_loss: 0.0046
# Epoch 7/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0045 - val_loss: 0.0070
# Epoch 8/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0050 - val_loss: 0.0051
# Epoch 9/300
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0050 - val_loss: 0.0061
# Epoch 10/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0053 - val_loss: 0.0058
# Epoch 11/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0065 - val_loss: 0.0056
# Epoch 12/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0063 - val_loss: 0.0054
# Epoch 13/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0052 - val_loss: 0.0068
# Epoch 14/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0049 - val_loss: 0.0060
# Epoch 15/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0048 - val_loss: 0.0065
# Epoch 16/300
# 24/24 [==============================] - 3s 120ms/step - loss: 0.0044 - val_loss: 0.0061
# Epoch 17/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0043 - val_loss: 0.0093
# Epoch 18/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0048 - val_loss: 0.0079
# Epoch 19/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0050 - val_loss: 0.0095
# Epoch 20/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0050 - val_loss: 0.0078
# Epoch 21/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0045 - val_loss: 0.0113
# Epoch 22/300
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0037 - val_loss: 0.0174
# Epoch 23/300
# 24/24 [==============================] - 3s 127ms/step - loss: 0.0040 - val_loss: 0.0171
# Epoch 24/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0047 - val_loss: 0.0244
# Epoch 25/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0031 - val_loss: 0.0231
# Epoch 26/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0042 - val_loss: 0.0098
# Epoch 27/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0067 - val_loss: 0.0139
# Epoch 28/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0038 - val_loss: 0.0226
# Epoch 29/300
# 24/24 [==============================] - 3s 125ms/step - loss: 0.0048 - val_loss: 0.0071
# Epoch 30/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0063 - val_loss: 0.0062
# Epoch 31/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0035 - val_loss: 0.0160
# 8/8 [==============================] - 1s 17ms/step
# Epoch 1/300
# 24/24 [==============================] - 16s 150ms/step - loss: 0.0497 - val_loss: 0.0849
# Epoch 2/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0628 - val_loss: 0.2138
# Epoch 3/300
# 24/24 [==============================] - 4s 151ms/step - loss: 0.0320 - val_loss: 0.1074
# Epoch 4/300
# 24/24 [==============================] - 3s 133ms/step - loss: 0.0230 - val_loss: 0.0172
# Epoch 5/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0095 - val_loss: 0.0087
# Epoch 6/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0061 - val_loss: 0.0069
# Epoch 7/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0080 - val_loss: 0.0066
# Epoch 8/300
# 24/24 [==============================] - 3s 128ms/step - loss: 0.0086 - val_loss: 0.0062
# Epoch 9/300
# 24/24 [==============================] - 4s 149ms/step - loss: 0.0073 - val_loss: 0.0061
# Epoch 10/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0068 - val_loss: 0.0073
# Epoch 11/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0055 - val_loss: 0.0094
# Epoch 12/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0058 - val_loss: 0.0090
# Epoch 13/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0051 - val_loss: 0.0130
# Epoch 14/300
# 24/24 [==============================] - 4s 154ms/step - loss: 0.0057 - val_loss: 0.0123
# Epoch 15/300
# 24/24 [==============================] - 3s 141ms/step - loss: 0.0061 - val_loss: 0.0122
# Epoch 16/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0052 - val_loss: 0.0163
# Epoch 17/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0043 - val_loss: 0.0207
# Epoch 18/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0037 - val_loss: 0.0199
# Epoch 19/300
# 24/24 [==============================] - 4s 153ms/step - loss: 0.0044 - val_loss: 0.0223
# Epoch 20/300
# 24/24 [==============================] - 3s 143ms/step - loss: 0.0055 - val_loss: 0.0174
# Epoch 21/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0049 - val_loss: 0.0231
# Epoch 22/300
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0051 - val_loss: 0.0257
# Epoch 23/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0051 - val_loss: 0.0266
# Epoch 24/300
# 24/24 [==============================] - 3s 144ms/step - loss: 0.0057 - val_loss: 0.0300
# Epoch 25/300
# 24/24 [==============================] - 4s 147ms/step - loss: 0.0054 - val_loss: 0.0320
# Epoch 26/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0036 - val_loss: 0.0398
# Epoch 27/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0041 - val_loss: 0.0112
# Epoch 28/300
# 24/24 [==============================] - 2s 103ms/step - loss: 0.0035 - val_loss: 0.0118
# Epoch 29/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0037 - val_loss: 0.0206
# Epoch 30/300
# 24/24 [==============================] - 3s 139ms/step - loss: 0.0043 - val_loss: 0.0204
# Epoch 31/300
# 24/24 [==============================] - 3s 135ms/step - loss: 0.0047 - val_loss: 0.0190
# Epoch 32/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0041 - val_loss: 0.0198
# Epoch 33/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0037 - val_loss: 0.0316
# Epoch 34/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0032 - val_loss: 0.0298
# 8/8 [==============================] - 1s 19ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 129ms/step - loss: 0.0509 - val_loss: 0.0915
# Epoch 2/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0589 - val_loss: 0.1670
# Epoch 3/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0386 - val_loss: 0.1280
# Epoch 4/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0176 - val_loss: 0.0084
# Epoch 5/300
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0085 - val_loss: 0.0130
# Epoch 6/300
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0108 - val_loss: 0.0113
# Epoch 7/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0105 - val_loss: 0.0136
# Epoch 8/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0099 - val_loss: 0.0236
# Epoch 9/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0091 - val_loss: 0.0094
# Epoch 10/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0046 - val_loss: 0.0128
# Epoch 11/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0061 - val_loss: 0.0111
# Epoch 12/300
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0065 - val_loss: 0.0106
# Epoch 13/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0070 - val_loss: 0.0097
# Epoch 14/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0051 - val_loss: 0.0087
# Epoch 15/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0060 - val_loss: 0.0112
# Epoch 16/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0056 - val_loss: 0.0092
# Epoch 17/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0047 - val_loss: 0.0111
# Epoch 18/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0045 - val_loss: 0.0117
# Epoch 19/300
# 24/24 [==============================] - 3s 126ms/step - loss: 0.0050 - val_loss: 0.0114
# Epoch 20/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0056 - val_loss: 0.0110
# Epoch 21/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0056 - val_loss: 0.0126
# Epoch 22/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0044 - val_loss: 0.0164
# Epoch 23/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0040 - val_loss: 0.0181
# Epoch 24/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0040 - val_loss: 0.0224
# Epoch 25/300
# 24/24 [==============================] - 3s 121ms/step - loss: 0.0037 - val_loss: 0.0215
# Epoch 26/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0039 - val_loss: 0.0321
# Epoch 27/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0041 - val_loss: 0.0253
# Epoch 28/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0039 - val_loss: 0.0290
# Epoch 29/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0043 - val_loss: 0.0265
# 8/8 [==============================] - 1s 17ms/step

# %%
with open('/content/drive/My Drive/thesis/notebooks/APPLE/model results/apple lstm results.json', "w") as file:
    json.dump(model_results, file)

# %%
#test for RMSE values


baseline_rmse = model_results['Prices'][1]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[1], 'rmse')
    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[1], 'rmse')

    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])

# %%
#test for MAE values


baseline_rmse = model_results['Prices'][2]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[2], 'mae')
    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[2], 'mae')

    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])

# %%
#test for accuracy values


baseline_rmse = model_results['Prices'][3]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[3], 'accuracy')
    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[3], 'accuracy')
    
    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])

# %%
with open('/content/drive/My Drive/thesis/notebooks/APPLE/model results/apple lstm test results.json', "w") as file:
    json.dump(test_results, file)
