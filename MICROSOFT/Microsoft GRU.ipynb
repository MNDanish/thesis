# %%
import yfinance as yf
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
from datetime import datetime
from keras.models import Sequential
from keras.layers import Dense, GRU
from keras.layers import LSTM
from keras import callbacks
from scipy.stats import wilcoxon, mannwhitneyu
from sklearn.preprocessing import MinMaxScaler
import math
from sklearn.metrics import mean_squared_error, mean_absolute_error
import tensorflow as tf

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_tweets = pd.read_csv('/content/drive/My Drive/thesis/datasets/twitter comments/tweets_sentiment.csv')
df_news = pd.read_csv('/content/drive/My Drive/thesis/datasets/news articles/news_sentiment_updated2.csv')
df_political_news = pd.read_csv('/content/drive/My Drive/thesis/datasets/news articles/political_news_sentiment.csv')

# %%
company_ticker = 'MSFT'
df_tweets.drop(columns='body', inplace=True)
df_tweets = df_tweets[df_tweets['ticker_symbol'] == company_ticker].reset_index(drop=True)
df_news = df_news[df_news['Company'] == 'Microsoft'].reset_index(drop=True)

# %%
dates = df_tweets['date'].unique()
avg_sentiment = []
tweets_volume = []

for date in dates:
    temp = df_tweets[df_tweets['date'] == date]
    avg_sentiment.append(temp['sentiment_score'].mean())
    tweets_volume.append(len(temp))
  
df_tweet_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_tweets':avg_sentiment, '# tweets' : tweets_volume})

# %%
df_news['Sentiment'] = df_news['Sentiment'].map({'positive': 1, 'neutral': 0, 'negative': -1})

dates = df_news['Date'].unique()
avg_sentiment = []
pos_count = []
neu_count = []
neg_count = []


for date in dates:
    temp = df_news[df_news['Date'] == date]
    avg_sentiment.append(temp['Sentiment'].mean())
    pos_count.append(len(temp[temp['Sentiment'] == 1]))
    neu_count.append(len(temp[temp['Sentiment'] == 0]))
    neg_count.append(len(temp[temp['Sentiment'] == -1]))

df_news_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_news':avg_sentiment, '# Positive news' : pos_count, 
                               '# Neutral news' : neu_count, '# Negative news' : neg_count})

# %%
df_political_news['Sentiment'] = df_political_news['Sentiment'].map({'Positive': 1, 'Neutral': 0, 'Negative': -1})

dates = df_political_news['Date'].unique()
avg_sentiment = []
pos_count = []
neu_count = []
neg_count = []


for date in dates:
    temp = df_political_news[df_political_news['Date'] == date]
    avg_sentiment.append(temp['Sentiment'].mean())
    pos_count.append(len(temp[temp['Sentiment'] == 1]))
    neu_count.append(len(temp[temp['Sentiment'] == 0]))
    neg_count.append(len(temp[temp['Sentiment'] == -1]))

df_political_news_scores = pd.DataFrame({'Date':dates, 'Avg_sentiment_polit_news':avg_sentiment, '# Positive polit_news' : pos_count, 
                               '# Neutral polit_news' : neu_count, '# Negative polit_news' : neg_count})

# %%
stock = yf.Ticker(company_ticker)

start = min(df_tweet_scores['Date'])
end = max(df_tweet_scores['Date'])

df = stock.history(start=pd.to_datetime(start).date(), end=pd.to_datetime(end).date())

# %%
df['Close'].plot(figsize=(6,3))
# Out:
# <Axes: xlabel='Date'>

# %%
df = df.reset_index()[['Date', 'Close']]
df['Date'] = df['Date'].apply(lambda x: datetime.strftime(pd.to_datetime(x), '%Y-%m-%d'))

df = pd.merge(df,df_tweet_scores,on='Date',how='inner')
df = pd.merge(df,df_news_scores,on='Date',how='inner')
df = pd.merge(df,df_political_news_scores,on='Date',how='left')

# %%
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-13-bf934754a5b1>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
def processData(data,lb):
    X,Y = [],[]
    data = data.to_numpy()
    for i in range(len(data)-lb-1):
        X.append(data[i:(i+lb),0])
        Y.append(data[(i+lb),0])
    return np.array(X),np.array(Y)

# %%
def processMultiData(data,lb):
    X,Y = [],[]
    df_as_np = data.to_numpy()
    for i in range(len(data)-lb-1):
        row = [r for r in df_as_np[i:i+lb]]
        X.append(row)
        Y.append(df_as_np[i+lb][0])
    return np.array(X),np.array(Y)

# %%
def train_test_data(feature_vector):
  lb=10
  train_size = 0.80

  data = df[feature_vector]
  scl = MinMaxScaler()
  multi_data = data.copy()
  train_data = data[0:int(len(df[['Close']])*0.80)]
  scl.fit(train_data)
  multi_data[feature_vector] = scl.transform(multi_data[feature_vector])

  if len(feature_vector) == 1:
    X,y = processData(multi_data,lb)
  else:
    X,y = processMultiData(multi_data,lb)

  X_train,X_test = X[:int(X.shape[0]*train_size)],X[int(X.shape[0]*train_size):]
  y_train,y_test = y[:int(y.shape[0]*train_size)],y[int(y.shape[0]*train_size):]  

  return X_train, X_test, y_train, y_test, scl

# %%
def create_model(X_train, y_train, feature_number, lb=10):
    tf.keras.backend.clear_session()
    tf.random.set_seed(51)
    np.random.seed(51)

    model = Sequential()

    model.add(GRU(units=128, dropout=0.2, recurrent_dropout=0.2, 
                  return_sequences=True, input_shape=(lb,feature_number)))
    model.add(GRU(units=64, dropout=0.2, recurrent_dropout=0.2, return_sequences=True))
    model.add(GRU(units=32, dropout=0.2, recurrent_dropout=0.2))

    model.add(Dense(units=16))
    model.add(Dense(units=1))

    model.compile(optimizer='adam', loss='mse')

    earlystopping = callbacks.EarlyStopping(monitor="val_loss", mode="min", 
                                            patience=25, restore_best_weights=True)

    X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], feature_number))

    history = model.fit(X_train, y_train, epochs=300, validation_split=0.2,
                        shuffle=False, callbacks=[earlystopping])

    return model

# %%
def make_predictions(X_test, y_test, model, feature_vector, scl):
  Xt = model.predict(X_test)
  Xt = Xt.flatten()
  some_features_actual = {"Actual":y_test}
  some_features_predicted = {"Predicted":Xt}

  for i in range(len(feature_vector) - 1):
    some_features_actual["null_val" + str(i)] = [0]* len(y_test)
    some_features_predicted["null_val" + str(i)] = [0]* len(Xt)
  
  df_actual = pd.DataFrame(some_features_actual)
  df_actual[list(some_features_actual.keys())] = scl.inverse_transform(df_actual[list(some_features_actual.keys())])

  df_predicted = pd.DataFrame(some_features_predicted)
  df_predicted[list(some_features_predicted.keys())] = scl.inverse_transform(df_predicted[list(some_features_predicted.keys())])

  test_rmse = math.sqrt(mean_squared_error(df_actual.Actual,df_predicted.Predicted))
  test_mae = mean_absolute_error(df_actual.Actual,df_predicted.Predicted) 


  y_pred_diff = [list(df_predicted.Predicted)[i] - list(df_predicted.Predicted)[i-1] for i in range(1, len(list(df_predicted.Predicted)))]
  y_test_diff = [list(df_actual.Actual)[i] - list(df_actual.Actual)[i-1] for i in range(1, len(list(df_actual.Actual)))]

  y_pred_movement = [1 if diff > 0 else 0 for diff in y_pred_diff]
  y_test_movement = [1 if diff > 0 else 0 for diff in y_test_diff]

  accuracy = sum([1 for pred, actual in zip(y_pred_movement, y_test_movement) if pred == actual]) / len(y_test_movement)

  return test_rmse, test_mae, accuracy, list(df_predicted.Predicted)

# %%
#Wilcoxon Signed Rank Test

def wilcoxon_signed_rank_test(arr1, arr2, metric):
  if metric != 'accuracy':
    statistic, p_value = wilcoxon(arr1, arr2, alternative='greater')
  else:
    statistic, p_value = wilcoxon(arr1, arr2, alternative='less')
  alpha = 0.05
  if p_value < alpha:
    return False #there is a difference
  return True #no difference

# %%
#Mann-Whitney U test

def mannwhitneyu_test(arr1, arr2, metric):
  if metric != 'accuracy':
    statistic, p_value = mannwhitneyu(arr1, arr2, alternative='greater')
  else:
    statistic, p_value = mannwhitneyu(arr1, arr2, alternative='less')
  alpha = 0.05
  if p_value < alpha:
    return False #there is a difference
  return True #no difference

# %%
model_results = {
    'Prices' : [['Close'], [], [], []],
    'Prices + Tweets' : [['Close', 'Avg_sentiment_tweets'], [], [], []],
    'Prices + News' : [['Close', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news'], [], [], []],
    'Prices + Political News' : [['Close', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + Tweets + News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news'], [], [], []],
    'Prices + Tweets + Political News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + News + Political News' : [['Close', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []],
    'Prices + Tweets + News + Political News' : [['Close', 'Avg_sentiment_tweets', 'Avg_sentiment_news', '# Positive news', '# Neutral news', '# Negative news', 'Avg_sentiment_polit_news', '# Positive polit_news', '# Neutral polit_news', '# Negative polit_news'], [], [], []]
}

# %%
test_results = {
    'RMSE Wilcoxon' : [],
    'MAE Wilcoxon' : [],
    'Accuracy Wilcoxon' : [],
    'RMSE Mann-Whitney' : [],
    'MAE Mann-Whitney' : [],
    'Accuracy Mann-Whitney' : []
}

# %%
for i in range(10):
  for key, item in model_results.items():
    feature_vector = model_results[key][0]
    X_train, X_test, y_train, y_test, scl = train_test_data(feature_vector)
    model = create_model(X_train, y_train, len(feature_vector))
    test_rmse, test_mae, accuracy, predicted_values = make_predictions(X_test, y_test, model, feature_vector, scl)
    model_results[key][1].append(round(test_rmse, 2))
    model_results[key][2].append(round(test_mae, 2))
    model_results[key][3].append(round(accuracy, 2))
# Out:
# Streaming output truncated to the last 5000 lines.
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0032 - val_loss: 0.0055
# Epoch 25/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0038 - val_loss: 0.0081
# Epoch 26/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0031 - val_loss: 0.0131
# Epoch 27/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0039 - val_loss: 0.0099
# Epoch 28/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0035 - val_loss: 0.0120
# Epoch 29/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0081 - val_loss: 0.0070
# Epoch 30/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0069 - val_loss: 0.0215
# Epoch 31/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0104 - val_loss: 0.0132
# 8/8 [==============================] - 1s 10ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 103ms/step - loss: 0.0047 - val_loss: 0.0125
# Epoch 2/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0323 - val_loss: 0.0042
# Epoch 3/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0245 - val_loss: 0.0186
# Epoch 4/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0140 - val_loss: 0.0054
# Epoch 5/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0042 - val_loss: 0.0021
# Epoch 6/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0121 - val_loss: 0.0041
# Epoch 7/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0067 - val_loss: 0.0026
# Epoch 8/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0108 - val_loss: 0.0054
# Epoch 9/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0071 - val_loss: 0.0033
# Epoch 10/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0139 - val_loss: 0.0075
# Epoch 11/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0043 - val_loss: 0.0013
# Epoch 12/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0048 - val_loss: 0.0021
# Epoch 13/300
# 24/24 [==============================] - 1s 63ms/step - loss: 0.0057 - val_loss: 0.0036
# Epoch 14/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0044 - val_loss: 0.0044
# Epoch 15/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0054 - val_loss: 0.0068
# Epoch 16/300
# 24/24 [==============================] - 2s 62ms/step - loss: 0.0041 - val_loss: 0.0061
# Epoch 17/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0099 - val_loss: 0.0025
# Epoch 18/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 19/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0090 - val_loss: 0.0041
# Epoch 20/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0057 - val_loss: 0.0045
# Epoch 21/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0117 - val_loss: 0.0035
# Epoch 22/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0057 - val_loss: 0.0037
# Epoch 23/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0034 - val_loss: 0.0019
# Epoch 24/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0078 - val_loss: 0.0146
# Epoch 25/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0049 - val_loss: 0.0063
# Epoch 26/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0118 - val_loss: 0.0135
# Epoch 27/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0019 - val_loss: 0.0023
# Epoch 28/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0089 - val_loss: 0.0148
# Epoch 29/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0043 - val_loss: 0.0080
# Epoch 30/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0082 - val_loss: 0.0123
# Epoch 31/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0042 - val_loss: 0.0030
# Epoch 32/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0117 - val_loss: 0.0112
# Epoch 33/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0052 - val_loss: 0.0146
# Epoch 34/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0035 - val_loss: 0.0044
# Epoch 35/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0105 - val_loss: 0.0226
# Epoch 36/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0074 - val_loss: 0.0070
# 8/8 [==============================] - 1s 10ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 135ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 2/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0385 - val_loss: 0.0040
# Epoch 3/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0596 - val_loss: 0.0029
# Epoch 4/300
# 24/24 [==============================] - 1s 50ms/step - loss: 0.0315 - val_loss: 0.0022
# Epoch 5/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0075 - val_loss: 0.0047
# Epoch 6/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0056 - val_loss: 0.0137
# Epoch 7/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0041 - val_loss: 0.0074
# Epoch 8/300
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0035 - val_loss: 0.0080
# Epoch 9/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0035 - val_loss: 0.0060
# Epoch 10/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0039 - val_loss: 0.0033
# Epoch 11/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0049 - val_loss: 0.0039
# Epoch 12/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0045 - val_loss: 0.0051
# Epoch 13/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0040 - val_loss: 0.0046
# Epoch 14/300
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0038 - val_loss: 0.0053
# Epoch 15/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0047 - val_loss: 0.0070
# Epoch 16/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0034 - val_loss: 0.0076
# Epoch 17/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0073 - val_loss: 0.0057
# Epoch 18/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0043 - val_loss: 0.0065
# Epoch 19/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0100 - val_loss: 0.0046
# Epoch 20/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0034 - val_loss: 0.0065
# Epoch 21/300
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0090 - val_loss: 0.0032
# Epoch 22/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0034 - val_loss: 0.0093
# Epoch 23/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0064 - val_loss: 0.0048
# Epoch 24/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0040 - val_loss: 0.0101
# Epoch 25/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0063 - val_loss: 0.0081
# Epoch 26/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0033 - val_loss: 0.0074
# Epoch 27/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0071 - val_loss: 0.0057
# Epoch 28/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0029 - val_loss: 0.0081
# Epoch 29/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0061 - val_loss: 0.0062
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 154ms/step - loss: 0.0060 - val_loss: 0.0043
# Epoch 2/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0354 - val_loss: 0.0041
# Epoch 3/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0476 - val_loss: 0.0204
# Epoch 4/300
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0302 - val_loss: 0.0059
# Epoch 5/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0074 - val_loss: 0.0025
# Epoch 6/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0065 - val_loss: 0.0041
# Epoch 7/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0054 - val_loss: 0.0048
# Epoch 8/300
# 24/24 [==============================] - 1s 52ms/step - loss: 0.0067 - val_loss: 0.0064
# Epoch 9/300
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0053 - val_loss: 0.0068
# Epoch 10/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0114 - val_loss: 0.0017
# Epoch 11/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 12/300
# 24/24 [==============================] - 1s 56ms/step - loss: 0.0098 - val_loss: 0.0015
# Epoch 13/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0046 - val_loss: 0.0041
# Epoch 14/300
# 24/24 [==============================] - 1s 51ms/step - loss: 0.0122 - val_loss: 0.0016
# Epoch 15/300
# 24/24 [==============================] - 1s 53ms/step - loss: 0.0039 - val_loss: 0.0021
# Epoch 16/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0074 - val_loss: 0.0119
# Epoch 17/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0056 - val_loss: 0.0030
# Epoch 18/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0123 - val_loss: 0.0069
# Epoch 19/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0027 - val_loss: 0.0022
# Epoch 20/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0086 - val_loss: 0.0125
# Epoch 21/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0065 - val_loss: 0.0114
# Epoch 22/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0114 - val_loss: 0.0057
# Epoch 23/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0040 - val_loss: 0.0036
# Epoch 24/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0104 - val_loss: 0.0159
# Epoch 25/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0038 - val_loss: 0.0031
# Epoch 26/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0103 - val_loss: 0.0126
# Epoch 27/300
# 24/24 [==============================] - 1s 54ms/step - loss: 0.0061 - val_loss: 0.0097
# Epoch 28/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0116 - val_loss: 0.0129
# Epoch 29/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 30/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0057 - val_loss: 0.0135
# Epoch 31/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0054 - val_loss: 0.0092
# Epoch 32/300
# 24/24 [==============================] - 1s 55ms/step - loss: 0.0108 - val_loss: 0.0076
# Epoch 33/300
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0079 - val_loss: 0.0042
# Epoch 34/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0167 - val_loss: 0.0188
# Epoch 35/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0055 - val_loss: 0.0228
# Epoch 36/300
# 24/24 [==============================] - 2s 62ms/step - loss: 0.0102 - val_loss: 0.0374
# Epoch 37/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0148 - val_loss: 0.0268
# 8/8 [==============================] - 3s 20ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 124ms/step - loss: 0.0059 - val_loss: 0.0082
# Epoch 2/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0479 - val_loss: 0.0055
# Epoch 3/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0611 - val_loss: 0.0046
# Epoch 4/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0455 - val_loss: 0.0015
# Epoch 5/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0150 - val_loss: 0.0020
# Epoch 6/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0077 - val_loss: 0.0102
# Epoch 7/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0114 - val_loss: 0.0020
# Epoch 8/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0055 - val_loss: 0.0085
# Epoch 9/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0092 - val_loss: 0.0020
# Epoch 10/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0040 - val_loss: 0.0053
# Epoch 11/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0052 - val_loss: 0.0018
# Epoch 12/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0033 - val_loss: 0.0062
# Epoch 13/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0047 - val_loss: 0.0053
# Epoch 14/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0032 - val_loss: 0.0052
# Epoch 15/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0058 - val_loss: 0.0036
# Epoch 16/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0035 - val_loss: 0.0054
# Epoch 17/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0063 - val_loss: 0.0140
# Epoch 18/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0045 - val_loss: 0.0065
# Epoch 19/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0114 - val_loss: 0.0015
# Epoch 20/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0039 - val_loss: 0.0058
# Epoch 21/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0060 - val_loss: 0.0048
# Epoch 22/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0044 - val_loss: 0.0080
# Epoch 23/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0100 - val_loss: 0.0040
# Epoch 24/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0042 - val_loss: 0.0067
# Epoch 25/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0109 - val_loss: 0.0065
# Epoch 26/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0034 - val_loss: 0.0025
# Epoch 27/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0109 - val_loss: 0.0087
# Epoch 28/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0047 - val_loss: 0.0045
# Epoch 29/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0036 - val_loss: 0.0055
# Epoch 30/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0055 - val_loss: 0.0173
# Epoch 31/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0055 - val_loss: 0.0086
# Epoch 32/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0136 - val_loss: 0.0144
# Epoch 33/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0055 - val_loss: 0.0037
# Epoch 34/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0125 - val_loss: 0.0140
# Epoch 35/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0035 - val_loss: 0.0061
# Epoch 36/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0054 - val_loss: 0.0186
# Epoch 37/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0037 - val_loss: 0.0069
# Epoch 38/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0121 - val_loss: 0.0147
# Epoch 39/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0135 - val_loss: 0.0280
# Epoch 40/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0274 - val_loss: 0.0124
# Epoch 41/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0214 - val_loss: 0.0265
# Epoch 42/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0069 - val_loss: 0.0189
# Epoch 43/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0074 - val_loss: 0.0211
# Epoch 44/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0116 - val_loss: 0.1079
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 161ms/step - loss: 0.0048 - val_loss: 0.0119
# Epoch 2/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0366 - val_loss: 0.0041
# Epoch 3/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0452 - val_loss: 0.0050
# Epoch 4/300
# 24/24 [==============================] - 3s 117ms/step - loss: 0.0468 - val_loss: 0.0018
# Epoch 5/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0163 - val_loss: 0.0024
# Epoch 6/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0066 - val_loss: 0.0063
# Epoch 7/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0075 - val_loss: 0.0039
# Epoch 8/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0073 - val_loss: 0.0111
# Epoch 9/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0147 - val_loss: 0.0012
# Epoch 10/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0041 - val_loss: 0.0068
# Epoch 11/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0046 - val_loss: 0.0020
# Epoch 12/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0032 - val_loss: 0.0053
# Epoch 13/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0046 - val_loss: 0.0037
# Epoch 14/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0033 - val_loss: 0.0081
# Epoch 15/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0052 - val_loss: 0.0051
# Epoch 16/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0031 - val_loss: 0.0060
# Epoch 17/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0053 - val_loss: 0.0111
# Epoch 18/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0033 - val_loss: 0.0058
# Epoch 19/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0066 - val_loss: 0.0021
# Epoch 20/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0033 - val_loss: 0.0073
# Epoch 21/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0044 - val_loss: 0.0047
# Epoch 22/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0035 - val_loss: 0.0084
# Epoch 23/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0056 - val_loss: 0.0051
# Epoch 24/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0028 - val_loss: 0.0082
# Epoch 25/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0060 - val_loss: 0.0052
# Epoch 26/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0027 - val_loss: 0.0078
# Epoch 27/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0058 - val_loss: 0.0064
# Epoch 28/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0029 - val_loss: 0.0075
# Epoch 29/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0052 - val_loss: 0.0058
# Epoch 30/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0032 - val_loss: 0.0090
# Epoch 31/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0055 - val_loss: 0.0048
# Epoch 32/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0029 - val_loss: 0.0103
# Epoch 33/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0041 - val_loss: 0.0067
# Epoch 34/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0026 - val_loss: 0.0085
# 8/8 [==============================] - 2s 17ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 141ms/step - loss: 0.0068 - val_loss: 0.0055
# Epoch 2/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0594 - val_loss: 0.0132
# Epoch 3/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0936 - val_loss: 0.1006
# Epoch 4/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0233 - val_loss: 0.0013
# Epoch 5/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0076 - val_loss: 0.0016
# Epoch 6/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0055 - val_loss: 0.0147
# Epoch 7/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0084 - val_loss: 0.0012
# Epoch 8/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0034 - val_loss: 0.0057
# Epoch 9/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0034 - val_loss: 0.0023
# Epoch 10/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0038 - val_loss: 0.0057
# Epoch 11/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0028 - val_loss: 0.0043
# Epoch 12/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0042 - val_loss: 0.0053
# Epoch 13/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0035 - val_loss: 0.0058
# Epoch 14/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0064 - val_loss: 0.0034
# Epoch 15/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0040 - val_loss: 0.0058
# Epoch 16/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0069 - val_loss: 0.0059
# Epoch 17/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0053 - val_loss: 0.0088
# Epoch 18/300
# 24/24 [==============================] - 2s 106ms/step - loss: 0.0073 - val_loss: 0.0048
# Epoch 19/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0049 - val_loss: 0.0100
# Epoch 20/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0145 - val_loss: 0.0018
# Epoch 21/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0038 - val_loss: 0.0056
# Epoch 22/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0048 - val_loss: 0.0066
# Epoch 23/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0052 - val_loss: 0.0154
# Epoch 24/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0095 - val_loss: 0.0024
# Epoch 25/300
# 24/24 [==============================] - 1s 63ms/step - loss: 0.0035 - val_loss: 0.0120
# Epoch 26/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0061 - val_loss: 0.0077
# Epoch 27/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0039 - val_loss: 0.0150
# Epoch 28/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0099 - val_loss: 0.0019
# Epoch 29/300
# 24/24 [==============================] - 1s 63ms/step - loss: 0.0043 - val_loss: 0.0117
# Epoch 30/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0036 - val_loss: 0.0135
# Epoch 31/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0033 - val_loss: 0.0180
# Epoch 32/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0025 - val_loss: 0.0126
# 8/8 [==============================] - 1s 10ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 119ms/step - loss: 0.0067 - val_loss: 0.0102
# Epoch 2/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0558 - val_loss: 0.0092
# Epoch 3/300
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0943 - val_loss: 0.0291
# Epoch 4/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0587 - val_loss: 0.0281
# Epoch 5/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0184 - val_loss: 0.0016
# Epoch 6/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0053 - val_loss: 0.0078
# Epoch 7/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0053 - val_loss: 0.0070
# Epoch 8/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0042 - val_loss: 0.0090
# Epoch 9/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0116 - val_loss: 0.0013
# Epoch 10/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0033 - val_loss: 0.0048
# Epoch 11/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0055 - val_loss: 0.0056
# Epoch 12/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0042 - val_loss: 0.0076
# Epoch 13/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0109 - val_loss: 0.0017
# Epoch 14/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0036 - val_loss: 0.0060
# Epoch 15/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0077 - val_loss: 0.0058
# Epoch 16/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0044 - val_loss: 0.0086
# Epoch 17/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0118 - val_loss: 0.0014
# Epoch 18/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0042 - val_loss: 0.0044
# Epoch 19/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0064 - val_loss: 0.0049
# Epoch 20/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0059 - val_loss: 0.0119
# Epoch 21/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0139 - val_loss: 0.0013
# Epoch 22/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0034 - val_loss: 0.0071
# Epoch 23/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0053 - val_loss: 0.0051
# Epoch 24/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0035 - val_loss: 0.0092
# Epoch 25/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0074 - val_loss: 0.0027
# Epoch 26/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0026 - val_loss: 0.0088
# Epoch 27/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0059 - val_loss: 0.0043
# Epoch 28/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0035 - val_loss: 0.0059
# Epoch 29/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0065 - val_loss: 0.0047
# Epoch 30/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0041 - val_loss: 0.0099
# Epoch 31/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0097 - val_loss: 0.0032
# Epoch 32/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0025 - val_loss: 0.0084
# Epoch 33/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0071 - val_loss: 0.0078
# Epoch 34/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0043 - val_loss: 0.0091
# 8/8 [==============================] - 1s 11ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 110ms/step - loss: 0.0036 - val_loss: 0.0069
# Epoch 2/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0123 - val_loss: 0.0140
# Epoch 3/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0168 - val_loss: 0.0022
# Epoch 4/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0094 - val_loss: 0.0028
# Epoch 5/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0091 - val_loss: 0.0019
# Epoch 6/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0065 - val_loss: 0.0044
# Epoch 7/300
# 24/24 [==============================] - 2s 103ms/step - loss: 0.0046 - val_loss: 0.0066
# Epoch 8/300
# 24/24 [==============================] - 4s 150ms/step - loss: 0.0107 - val_loss: 0.0019
# Epoch 9/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0094 - val_loss: 0.0024
# Epoch 10/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0072 - val_loss: 0.0049
# Epoch 11/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0104 - val_loss: 0.0054
# Epoch 12/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0053 - val_loss: 0.0021
# Epoch 13/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0074 - val_loss: 0.0081
# Epoch 14/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0081 - val_loss: 0.0031
# Epoch 15/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0120 - val_loss: 0.0015
# Epoch 16/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0045 - val_loss: 0.0027
# Epoch 17/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0047 - val_loss: 0.0032
# Epoch 18/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0057 - val_loss: 0.0073
# Epoch 19/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0067 - val_loss: 0.0158
# Epoch 20/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0109 - val_loss: 0.0222
# Epoch 21/300
# 24/24 [==============================] - 1s 62ms/step - loss: 0.0031 - val_loss: 0.0034
# Epoch 22/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0070 - val_loss: 0.0133
# Epoch 23/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0060 - val_loss: 0.0065
# Epoch 24/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0100 - val_loss: 0.0126
# Epoch 25/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0030 - val_loss: 0.0111
# Epoch 26/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0025 - val_loss: 0.0190
# Epoch 27/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0015 - val_loss: 0.0167
# Epoch 28/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0013 - val_loss: 0.0147
# Epoch 29/300
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0018 - val_loss: 0.0190
# Epoch 30/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0011 - val_loss: 0.0234
# Epoch 31/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0029 - val_loss: 0.0268
# Epoch 32/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0032 - val_loss: 0.0248
# Epoch 33/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0080 - val_loss: 0.0210
# Epoch 34/300
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0049 - val_loss: 0.0103
# Epoch 35/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0121 - val_loss: 0.0269
# Epoch 36/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0061 - val_loss: 0.0631
# Epoch 37/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0054 - val_loss: 0.0170
# Epoch 38/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0104 - val_loss: 0.0554
# Epoch 39/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0017 - val_loss: 0.0203
# Epoch 40/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0053 - val_loss: 0.0613
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 15s 159ms/step - loss: 0.0049 - val_loss: 0.0146
# Epoch 2/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0308 - val_loss: 0.0022
# Epoch 3/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0191 - val_loss: 0.0169
# Epoch 4/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0145 - val_loss: 0.0014
# Epoch 5/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0046 - val_loss: 0.0015
# Epoch 6/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0115 - val_loss: 0.0021
# Epoch 7/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0088 - val_loss: 0.0065
# Epoch 8/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0119 - val_loss: 0.0027
# Epoch 9/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0062 - val_loss: 0.0023
# Epoch 10/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0135 - val_loss: 0.0028
# Epoch 11/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0037 - val_loss: 0.0029
# Epoch 12/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0103 - val_loss: 0.0030
# Epoch 13/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0054 - val_loss: 0.0054
# Epoch 14/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0084 - val_loss: 0.0022
# Epoch 15/300
# 24/24 [==============================] - 3s 129ms/step - loss: 0.0069 - val_loss: 0.0124
# Epoch 16/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0062 - val_loss: 0.0037
# Epoch 17/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0037 - val_loss: 0.0066
# Epoch 18/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0043 - val_loss: 0.0052
# Epoch 19/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0038 - val_loss: 0.0084
# Epoch 20/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0040 - val_loss: 0.0078
# Epoch 21/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0034 - val_loss: 0.0142
# Epoch 22/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0030 - val_loss: 0.0107
# Epoch 23/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0025 - val_loss: 0.0051
# Epoch 24/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0035 - val_loss: 0.0081
# Epoch 25/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0025 - val_loss: 0.0125
# Epoch 26/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0029 - val_loss: 0.0103
# Epoch 27/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0026 - val_loss: 0.0083
# Epoch 28/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0025 - val_loss: 0.0096
# Epoch 29/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0026 - val_loss: 0.0099
# 8/8 [==============================] - 1s 17ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 122ms/step - loss: 0.0038 - val_loss: 0.0030
# Epoch 2/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0404 - val_loss: 0.0128
# Epoch 3/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0659 - val_loss: 0.0163
# Epoch 4/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0254 - val_loss: 0.0023
# Epoch 5/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0048 - val_loss: 0.0042
# Epoch 6/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0112 - val_loss: 0.0033
# Epoch 7/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0092 - val_loss: 0.0187
# Epoch 8/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0158 - val_loss: 0.0025
# Epoch 9/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0058 - val_loss: 0.0120
# Epoch 10/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 11/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0062 - val_loss: 0.0027
# Epoch 12/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0040 - val_loss: 0.0087
# Epoch 13/300
# 24/24 [==============================] - 1s 59ms/step - loss: 0.0050 - val_loss: 0.0025
# Epoch 14/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0040 - val_loss: 0.0090
# Epoch 15/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0038 - val_loss: 0.0088
# Epoch 16/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0027 - val_loss: 0.0108
# Epoch 17/300
# 24/24 [==============================] - 1s 60ms/step - loss: 0.0038 - val_loss: 0.0054
# Epoch 18/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0036 - val_loss: 0.0098
# Epoch 19/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0035 - val_loss: 0.0087
# Epoch 20/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0030 - val_loss: 0.0073
# Epoch 21/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0036 - val_loss: 0.0071
# Epoch 22/300
# 24/24 [==============================] - 1s 57ms/step - loss: 0.0034 - val_loss: 0.0090
# Epoch 23/300
# 24/24 [==============================] - 1s 58ms/step - loss: 0.0032 - val_loss: 0.0084
# Epoch 24/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0030 - val_loss: 0.0104
# Epoch 25/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0031 - val_loss: 0.0124
# Epoch 26/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0027 - val_loss: 0.0090
# Epoch 27/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0037 - val_loss: 0.0087
# Epoch 28/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0027 - val_loss: 0.0063
# Epoch 29/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0059 - val_loss: 0.0072
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 114ms/step - loss: 0.0090 - val_loss: 0.0054
# Epoch 2/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0284 - val_loss: 0.0065
# Epoch 3/300
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0311 - val_loss: 0.0043
# Epoch 4/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0223 - val_loss: 0.0066
# Epoch 5/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0135 - val_loss: 0.0016
# Epoch 6/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0054 - val_loss: 0.0022
# Epoch 7/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0038 - val_loss: 0.0018
# Epoch 8/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0065 - val_loss: 0.0040
# Epoch 9/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0061 - val_loss: 0.0057
# Epoch 10/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0134 - val_loss: 0.0019
# Epoch 11/300
# 24/24 [==============================] - 3s 111ms/step - loss: 0.0053 - val_loss: 0.0033
# Epoch 12/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0143 - val_loss: 0.0039
# Epoch 13/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0041 - val_loss: 0.0034
# Epoch 14/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0142 - val_loss: 0.0121
# Epoch 15/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0051 - val_loss: 0.0047
# Epoch 16/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0043 - val_loss: 0.0054
# Epoch 17/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0089 - val_loss: 0.0036
# Epoch 18/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0080 - val_loss: 0.0211
# Epoch 19/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0127 - val_loss: 0.0013
# Epoch 20/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0034 - val_loss: 0.0085
# Epoch 21/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0043 - val_loss: 0.0091
# Epoch 22/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0037 - val_loss: 0.0150
# Epoch 23/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0035 - val_loss: 0.0068
# Epoch 24/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0032 - val_loss: 0.0134
# Epoch 25/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0029 - val_loss: 0.0107
# Epoch 26/300
# 24/24 [==============================] - 3s 118ms/step - loss: 0.0028 - val_loss: 0.0100
# Epoch 27/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0033 - val_loss: 0.0057
# Epoch 28/300
# 24/24 [==============================] - 2s 70ms/step - loss: 0.0027 - val_loss: 0.0084
# Epoch 29/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0034 - val_loss: 0.0062
# Epoch 30/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0028 - val_loss: 0.0121
# Epoch 31/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0028 - val_loss: 0.0097
# Epoch 32/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0025 - val_loss: 0.0074
# Epoch 33/300
# 24/24 [==============================] - 3s 119ms/step - loss: 0.0029 - val_loss: 0.0086
# Epoch 34/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0032 - val_loss: 0.0089
# Epoch 35/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0018 - val_loss: 0.0149
# Epoch 36/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0023 - val_loss: 0.0082
# Epoch 37/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0016 - val_loss: 0.0082
# Epoch 38/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0031 - val_loss: 0.0190
# Epoch 39/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0016 - val_loss: 0.0117
# Epoch 40/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0046 - val_loss: 0.0171
# Epoch 41/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0033 - val_loss: 0.0064
# Epoch 42/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0095 - val_loss: 0.0134
# Epoch 43/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0030 - val_loss: 0.0149
# Epoch 44/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0028 - val_loss: 0.0104
# 8/8 [==============================] - 1s 12ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 109ms/step - loss: 0.0062 - val_loss: 0.0102
# Epoch 2/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0785 - val_loss: 0.0337
# Epoch 3/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0484 - val_loss: 0.0069
# Epoch 4/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0190 - val_loss: 0.0017
# Epoch 5/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0042 - val_loss: 0.0074
# Epoch 6/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0102 - val_loss: 0.0015
# Epoch 7/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0055 - val_loss: 0.0138
# Epoch 8/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0058 - val_loss: 0.0018
# Epoch 9/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0037 - val_loss: 0.0066
# Epoch 10/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0034 - val_loss: 0.0042
# Epoch 11/300
# 24/24 [==============================] - 2s 68ms/step - loss: 0.0035 - val_loss: 0.0033
# Epoch 12/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0034 - val_loss: 0.0055
# Epoch 13/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0038 - val_loss: 0.0050
# Epoch 14/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0033 - val_loss: 0.0072
# Epoch 15/300
# 24/24 [==============================] - 2s 67ms/step - loss: 0.0044 - val_loss: 0.0091
# Epoch 16/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0029 - val_loss: 0.0058
# Epoch 17/300
# 24/24 [==============================] - 2s 63ms/step - loss: 0.0063 - val_loss: 0.0161
# Epoch 18/300
# 24/24 [==============================] - 2s 64ms/step - loss: 0.0039 - val_loss: 0.0066
# Epoch 19/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0106 - val_loss: 0.0026
# Epoch 20/300
# 24/24 [==============================] - 1s 61ms/step - loss: 0.0027 - val_loss: 0.0050
# Epoch 21/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0053 - val_loss: 0.0059
# Epoch 22/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0047 - val_loss: 0.0099
# Epoch 23/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0076 - val_loss: 0.0095
# Epoch 24/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0034 - val_loss: 0.0082
# Epoch 25/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0093 - val_loss: 0.0077
# Epoch 26/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0024 - val_loss: 0.0084
# Epoch 27/300
# 24/24 [==============================] - 2s 66ms/step - loss: 0.0073 - val_loss: 0.0103
# Epoch 28/300
# 24/24 [==============================] - 2s 65ms/step - loss: 0.0037 - val_loss: 0.0062
# Epoch 29/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0061 - val_loss: 0.0115
# Epoch 30/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0044 - val_loss: 0.0057
# Epoch 31/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0095 - val_loss: 0.0082
# 8/8 [==============================] - 1s 11ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 120ms/step - loss: 0.0064 - val_loss: 0.0131
# Epoch 2/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0353 - val_loss: 0.0032
# Epoch 3/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0481 - val_loss: 0.0065
# Epoch 4/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0462 - val_loss: 0.0019
# Epoch 5/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0174 - val_loss: 0.0015
# Epoch 6/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0079 - val_loss: 0.0071
# Epoch 7/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0117 - val_loss: 0.0017
# Epoch 8/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0091 - val_loss: 0.0197
# Epoch 9/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0146 - val_loss: 0.0015
# Epoch 10/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0061 - val_loss: 0.0061
# Epoch 11/300
# 24/24 [==============================] - 2s 69ms/step - loss: 0.0034 - val_loss: 0.0066
# Epoch 12/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0039 - val_loss: 0.0043
# Epoch 13/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0034 - val_loss: 0.0074
# Epoch 14/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0028 - val_loss: 0.0071
# Epoch 15/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0037 - val_loss: 0.0061
# Epoch 16/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0034 - val_loss: 0.0074
# Epoch 17/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0039 - val_loss: 0.0123
# Epoch 18/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0033 - val_loss: 0.0084
# Epoch 19/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0038 - val_loss: 0.0075
# Epoch 20/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0029 - val_loss: 0.0085
# Epoch 21/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0039 - val_loss: 0.0069
# Epoch 22/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0028 - val_loss: 0.0093
# Epoch 23/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0049 - val_loss: 0.0059
# Epoch 24/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0034 - val_loss: 0.0103
# Epoch 25/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0066 - val_loss: 0.0066
# Epoch 26/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0027 - val_loss: 0.0086
# Epoch 27/300
# 24/24 [==============================] - 3s 113ms/step - loss: 0.0077 - val_loss: 0.0047
# Epoch 28/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0034 - val_loss: 0.0082
# Epoch 29/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0059 - val_loss: 0.0081
# Epoch 30/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0041 - val_loss: 0.0077
# Epoch 31/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0085 - val_loss: 0.0089
# Epoch 32/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0022 - val_loss: 0.0064
# Epoch 33/300
# 24/24 [==============================] - 2s 72ms/step - loss: 0.0062 - val_loss: 0.0099
# Epoch 34/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0047 - val_loss: 0.0069
# 8/8 [==============================] - 1s 18ms/step
# Epoch 1/300
# 24/24 [==============================] - 15s 165ms/step - loss: 0.0089 - val_loss: 0.0048
# Epoch 2/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0738 - val_loss: 0.0045
# Epoch 3/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0789 - val_loss: 0.0713
# Epoch 4/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0233 - val_loss: 0.0027
# Epoch 5/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0064 - val_loss: 0.0013
# Epoch 6/300
# 24/24 [==============================] - 2s 71ms/step - loss: 0.0042 - val_loss: 0.0058
# Epoch 7/300
# ...
# Epoch 9/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0038 - val_loss: 0.0046
# Epoch 10/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0096 - val_loss: 0.0019
# Epoch 11/300
# 24/24 [==============================] - 3s 116ms/step - loss: 0.0053 - val_loss: 0.0014
# Epoch 12/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0067 - val_loss: 0.0035
# Epoch 13/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0061 - val_loss: 0.0041
# Epoch 14/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0195 - val_loss: 0.0013
# Epoch 15/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0034 - val_loss: 0.0020
# Epoch 16/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0068 - val_loss: 0.0109
# Epoch 17/300
# 24/24 [==============================] - 2s 91ms/step - loss: 0.0045 - val_loss: 0.0048
# Epoch 18/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0109 - val_loss: 0.0068
# Epoch 19/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0039 - val_loss: 0.0019
# Epoch 20/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0087 - val_loss: 0.0133
# Epoch 21/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0049 - val_loss: 0.0038
# Epoch 22/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0082 - val_loss: 0.0060
# Epoch 23/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0067 - val_loss: 0.0058
# Epoch 24/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0137 - val_loss: 0.0212
# Epoch 25/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0029 - val_loss: 0.0052
# Epoch 26/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0054 - val_loss: 0.0058
# Epoch 27/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0050 - val_loss: 0.0116
# Epoch 28/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0064 - val_loss: 0.0035
# Epoch 29/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0055 - val_loss: 0.0138
# Epoch 30/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0091 - val_loss: 0.0029
# Epoch 31/300
# 24/24 [==============================] - 2s 79ms/step - loss: 0.0044 - val_loss: 0.0114
# 8/8 [==============================] - 1s 13ms/step
# Epoch 1/300
# 24/24 [==============================] - 14s 126ms/step - loss: 0.0096 - val_loss: 0.0047
# Epoch 2/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0569 - val_loss: 0.0135
# Epoch 3/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0646 - val_loss: 0.0188
# Epoch 4/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0259 - val_loss: 0.0019
# Epoch 5/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0039 - val_loss: 0.0032
# Epoch 6/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0081 - val_loss: 0.0014
# Epoch 7/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0057 - val_loss: 0.0122
# Epoch 8/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0075 - val_loss: 0.0013
# Epoch 9/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0043 - val_loss: 0.0057
# Epoch 10/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 11/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0050 - val_loss: 0.0020
# Epoch 12/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0034 - val_loss: 0.0051
# Epoch 13/300
# 24/24 [==============================] - 2s 95ms/step - loss: 0.0057 - val_loss: 0.0065
# Epoch 14/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0043 - val_loss: 0.0070
# Epoch 15/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0107 - val_loss: 0.0017
# Epoch 16/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0033 - val_loss: 0.0045
# Epoch 17/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0051 - val_loss: 0.0091
# Epoch 18/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0045 - val_loss: 0.0078
# Epoch 19/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0088 - val_loss: 0.0024
# Epoch 20/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0034 - val_loss: 0.0059
# Epoch 21/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0053 - val_loss: 0.0049
# Epoch 22/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0040 - val_loss: 0.0082
# Epoch 23/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0073 - val_loss: 0.0059
# Epoch 24/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0033 - val_loss: 0.0094
# Epoch 25/300
# 24/24 [==============================] - 2s 93ms/step - loss: 0.0076 - val_loss: 0.0069
# Epoch 26/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0029 - val_loss: 0.0081
# Epoch 27/300
# 24/24 [==============================] - 2s 101ms/step - loss: 0.0076 - val_loss: 0.0064
# Epoch 28/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0037 - val_loss: 0.0073
# Epoch 29/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0050 - val_loss: 0.0076
# Epoch 30/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0049 - val_loss: 0.0127
# Epoch 31/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0062 - val_loss: 0.0063
# Epoch 32/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0033 - val_loss: 0.0108
# Epoch 33/300
# 24/24 [==============================] - 3s 115ms/step - loss: 0.0041 - val_loss: 0.0085
# 8/8 [==============================] - 1s 19ms/step
# Epoch 1/300
# 24/24 [==============================] - 12s 160ms/step - loss: 0.0062 - val_loss: 0.0112
# Epoch 2/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0410 - val_loss: 0.0043
# Epoch 3/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0417 - val_loss: 0.0174
# Epoch 4/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0460 - val_loss: 0.0017
# Epoch 5/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0179 - val_loss: 0.0021
# Epoch 6/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0079 - val_loss: 0.0085
# Epoch 7/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0143 - val_loss: 0.0014
# Epoch 8/300
# 24/24 [==============================] - 2s 102ms/step - loss: 0.0059 - val_loss: 0.0088
# Epoch 9/300
# 24/24 [==============================] - 2s 103ms/step - loss: 0.0105 - val_loss: 0.0020
# Epoch 10/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0072 - val_loss: 0.0158
# Epoch 11/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0153 - val_loss: 0.0023
# Epoch 12/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0069 - val_loss: 0.0098
# Epoch 13/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0043 - val_loss: 0.0110
# Epoch 14/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0034 - val_loss: 0.0059
# Epoch 15/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0032 - val_loss: 0.0059
# Epoch 16/300
# 24/24 [==============================] - 2s 100ms/step - loss: 0.0035 - val_loss: 0.0057
# Epoch 17/300
# 24/24 [==============================] - 2s 97ms/step - loss: 0.0033 - val_loss: 0.0135
# Epoch 18/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0034 - val_loss: 0.0074
# Epoch 19/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0027 - val_loss: 0.0079
# Epoch 20/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0036 - val_loss: 0.0069
# Epoch 21/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0032 - val_loss: 0.0099
# Epoch 22/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0041 - val_loss: 0.0073
# Epoch 23/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0034 - val_loss: 0.0090
# Epoch 24/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0057 - val_loss: 0.0083
# Epoch 25/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0037 - val_loss: 0.0114
# Epoch 26/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0102 - val_loss: 0.0032
# Epoch 27/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0031 - val_loss: 0.0111
# Epoch 28/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0064 - val_loss: 0.0030
# Epoch 29/300
# 24/24 [==============================] - 2s 74ms/step - loss: 0.0046 - val_loss: 0.0118
# Epoch 30/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0083 - val_loss: 0.0102
# Epoch 31/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0034 - val_loss: 0.0048
# Epoch 32/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0088 - val_loss: 0.0163
# 8/8 [==============================] - 1s 16ms/step
# Epoch 1/300
# 24/24 [==============================] - 16s 124ms/step - loss: 0.0216 - val_loss: 0.0028
# Epoch 2/300
# 24/24 [==============================] - 2s 96ms/step - loss: 0.0382 - val_loss: 0.0044
# Epoch 3/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0310 - val_loss: 0.0050
# Epoch 4/300
# 24/24 [==============================] - 2s 98ms/step - loss: 0.0250 - val_loss: 0.0024
# Epoch 5/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0142 - val_loss: 0.0038
# Epoch 6/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0097 - val_loss: 0.0018
# Epoch 7/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0038 - val_loss: 0.0033
# Epoch 8/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0096 - val_loss: 0.0014
# Epoch 9/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0037 - val_loss: 0.0028
# Epoch 10/300
# 24/24 [==============================] - 2s 104ms/step - loss: 0.0095 - val_loss: 0.0037
# Epoch 11/300
# 24/24 [==============================] - 3s 110ms/step - loss: 0.0043 - val_loss: 0.0048
# Epoch 12/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0149 - val_loss: 0.0016
# Epoch 13/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0041 - val_loss: 0.0036
# Epoch 14/300
# 24/24 [==============================] - 2s 83ms/step - loss: 0.0115 - val_loss: 0.0017
# Epoch 15/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0043 - val_loss: 0.0047
# Epoch 16/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0098 - val_loss: 0.0029
# Epoch 17/300
# 24/24 [==============================] - 3s 114ms/step - loss: 0.0049 - val_loss: 0.0028
# Epoch 18/300
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0078 - val_loss: 0.0067
# Epoch 19/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0054 - val_loss: 0.0056
# Epoch 20/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0142 - val_loss: 0.0017
# Epoch 21/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0036 - val_loss: 0.0032
# Epoch 22/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0098 - val_loss: 0.0121
# Epoch 23/300
# 24/24 [==============================] - 2s 87ms/step - loss: 0.0065 - val_loss: 0.0035
# Epoch 24/300
# 24/24 [==============================] - 3s 112ms/step - loss: 0.0170 - val_loss: 0.0098
# Epoch 25/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0113 - val_loss: 0.0247
# Epoch 26/300
# 24/24 [==============================] - 2s 86ms/step - loss: 0.0072 - val_loss: 0.0104
# Epoch 27/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0087 - val_loss: 0.0156
# Epoch 28/300
# 24/24 [==============================] - 2s 85ms/step - loss: 0.0054 - val_loss: 0.0037
# Epoch 29/300
# 24/24 [==============================] - 2s 82ms/step - loss: 0.0107 - val_loss: 0.0146
# Epoch 30/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0053 - val_loss: 0.0047
# Epoch 31/300
# 24/24 [==============================] - 3s 108ms/step - loss: 0.0143 - val_loss: 0.0210
# Epoch 32/300
# 24/24 [==============================] - 3s 109ms/step - loss: 0.0031 - val_loss: 0.0031
# Epoch 33/300
# 24/24 [==============================] - 2s 84ms/step - loss: 0.0114 - val_loss: 0.0170
# 8/8 [==============================] - 1s 14ms/step
# Epoch 1/300
# 24/24 [==============================] - 13s 123ms/step - loss: 0.0063 - val_loss: 0.0041
# Epoch 2/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0481 - val_loss: 0.0073
# Epoch 3/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0624 - val_loss: 0.0030
# Epoch 4/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0540 - val_loss: 0.0072
# Epoch 5/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0220 - val_loss: 0.0020
# Epoch 6/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0060 - val_loss: 0.0068
# Epoch 7/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0092 - val_loss: 0.0035
# Epoch 8/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0073 - val_loss: 0.0197
# Epoch 9/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0169 - val_loss: 0.0013
# Epoch 10/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0060 - val_loss: 0.0049
# Epoch 11/300
# 24/24 [==============================] - 2s 78ms/step - loss: 0.0041 - val_loss: 0.0092
# Epoch 12/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0049 - val_loss: 0.0031
# Epoch 13/300
# 24/24 [==============================] - 2s 94ms/step - loss: 0.0033 - val_loss: 0.0044
# Epoch 14/300
# 24/24 [==============================] - 3s 105ms/step - loss: 0.0035 - val_loss: 0.0042
# Epoch 15/300
# 24/24 [==============================] - 2s 89ms/step - loss: 0.0028 - val_loss: 0.0099
# Epoch 16/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0026 - val_loss: 0.0054
# Epoch 17/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0037 - val_loss: 0.0033
# Epoch 18/300
# 24/24 [==============================] - 2s 81ms/step - loss: 0.0036 - val_loss: 0.0041
# Epoch 19/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0049 - val_loss: 0.0077
# Epoch 20/300
# 24/24 [==============================] - 2s 80ms/step - loss: 0.0035 - val_loss: 0.0055
# Epoch 21/300
# 24/24 [==============================] - 2s 99ms/step - loss: 0.0080 - val_loss: 0.0119
# Epoch 22/300
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0044 - val_loss: 0.0073
# Epoch 23/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0132 - val_loss: 0.0032
# Epoch 24/300
# 24/24 [==============================] - 2s 88ms/step - loss: 0.0037 - val_loss: 0.0049
# Epoch 25/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0105 - val_loss: 0.0061
# Epoch 26/300
# 24/24 [==============================] - 2s 77ms/step - loss: 0.0050 - val_loss: 0.0032
# Epoch 27/300
# 24/24 [==============================] - 2s 76ms/step - loss: 0.0118 - val_loss: 0.0096
# Epoch 28/300
# 24/24 [==============================] - 2s 90ms/step - loss: 0.0047 - val_loss: 0.0018
# Epoch 29/300
# 24/24 [==============================] - 3s 107ms/step - loss: 0.0036 - val_loss: 0.0036
# Epoch 30/300
# 24/24 [==============================] - 2s 92ms/step - loss: 0.0046 - val_loss: 0.0085
# Epoch 31/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0040 - val_loss: 0.0076
# Epoch 32/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0093 - val_loss: 0.0130
# Epoch 33/300
# 24/24 [==============================] - 2s 73ms/step - loss: 0.0055 - val_loss: 0.0107
# Epoch 34/300
# 24/24 [==============================] - 2s 75ms/step - loss: 0.0130 - val_loss: 0.0127
# 8/8 [==============================] - 1s 13ms/step

# %%
with open('/content/drive/My Drive/thesis/notebooks/MICROSOFT/model results/microsoft gru results.json', "w") as file:
    json.dump(model_results, file)

# %%
#test for RMSE values


baseline_rmse = model_results['Prices'][1]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[1], 'rmse')

    if wilcoxon_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using wilcoxon\n')
    else:
      print(f'No difference between model with Prices and model with {key} using wilcoxon\n')

    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[1], 'rmse')
    
    if mannwhitneyu_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using mannwhitneyu\n')
    else:
      print(f'No difference between model with Prices and model with {key} using mannwhitneyu\n')

    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])
# Out:
# There is a difference between model with Prices and model with Prices + Tweets using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Political News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using mannwhitneyu
#
# No difference between model with Prices and model with Prices + News + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + News + Political News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + News + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + News + Political News using mannwhitneyu

# %%
#test for MAE values


baseline_rmse = model_results['Prices'][2]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[2], 'mae')

    if wilcoxon_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using wilcoxon\n')
    else:
      print(f'No difference between model with Prices and model with {key} using wilcoxon\n')

    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[2], 'mae')
    
    if mannwhitneyu_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using mannwhitneyu\n')
    else:
      print(f'No difference between model with Prices and model with {key} using mannwhitneyu\n')

    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])
# Out:
# There is a difference between model with Prices and model with Prices + Tweets using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Political News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using mannwhitneyu
#
# No difference between model with Prices and model with Prices + News + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + News + Political News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + News + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + News + Political News using mannwhitneyu

# %%
#test for accuracy values


baseline_rmse = model_results['Prices'][3]
for key, item in model_results.items():
  if key != 'Prices':
    wilcoxon_rmse_result = wilcoxon_signed_rank_test(baseline_rmse, item[3], 'accuracy')

    if wilcoxon_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using wilcoxon\n')
    else:
      print(f'No difference between model with Prices and model with {key} using wilcoxon\n')

    mannwhitneyu_rmse_result = mannwhitneyu_test(baseline_rmse, item[3], 'accuracy')
    
    if mannwhitneyu_rmse_result == False:
      print(f'There is a difference between model with Prices and model with {key} using mannwhitneyu\n')
    else:
      print(f'No difference between model with Prices and model with {key} using mannwhitneyu\n')

    test_results['RMSE Wilcoxon'].append(['Prices', key, wilcoxon_rmse_result])
    test_results['RMSE Mann-Whitney'].append(['Prices', key, mannwhitneyu_rmse_result])
# Out:
# There is a difference between model with Prices and model with Prices + Tweets using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets using mannwhitneyu
#
# No difference between model with Prices and model with Prices + News using wilcoxon
#
# No difference between model with Prices and model with Prices + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Political News using mannwhitneyu
#
# No difference between model with Prices and model with Prices + Tweets + News using wilcoxon
#
# No difference between model with Prices and model with Prices + Tweets + News using mannwhitneyu
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using wilcoxon
#
# There is a difference between model with Prices and model with Prices + Tweets + Political News using mannwhitneyu
#
# No difference between model with Prices and model with Prices + News + Political News using wilcoxon
#
# No difference between model with Prices and model with Prices + News + Political News using mannwhitneyu
#
# No difference between model with Prices and model with Prices + Tweets + News + Political News using wilcoxon
#
# No difference between model with Prices and model with Prices + Tweets + News + Political News using mannwhitneyu
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:3414: UserWarning: Exact p-value calculation does not work if there are zeros. Switching to normal approximation.
#   warnings.warn("Exact p-value calculation does not work if there are "
# /usr/local/lib/python3.10/dist-packages/scipy/stats/_morestats.py:3428: UserWarning: Sample size too small for normal approximation.
#   warnings.warn("Sample size too small for normal approximation.")

# %%
with open('/content/drive/My Drive/thesis/notebooks/MICROSOFT/model results/microsoft gru test results.json', "w") as file:
    json.dump(test_results, file)
